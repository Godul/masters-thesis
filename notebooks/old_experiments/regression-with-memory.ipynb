# %% [markdown]
# # Regression with memory usage

# %% [markdown]
# ## Redis YCSB 12x20min

# %%
from helpers.helpers_old import (
    draw_regression_graph,
    fit_regression,
    get_data_with_metrics,
)

experiments_path = '../../data'
experiment_name = 'redis_ycsb_12x20'

exp_name, df = next(get_data_with_metrics(experiment_name, experiments_path, instances_n=12))

df.head()
# Out:
#   cbtool_time    cpu_time  app_latency  app_throughput     cpu        memory  \
# 0  1591872872  1591872871     0.079693     9487.666034  1572.0  4.553658e+09
# 1  1591872933  1591872932     0.078356    10040.160643  1627.0  4.483006e+09
# 2  1591872994  1591872992     0.077941     9950.248756  1655.0  4.633547e+09
# 3  1591873055  1591873053     0.076327    10080.645161  1704.0  4.555633e+09
# 4  1591873111  1591873113     0.082048     9199.632015  1638.0  4.475527e+09
#
#    instances_n
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ### `app_latency` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     2932.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):          5.47e-134
# Time:                        15:49:10   Log-Likelihood:                 874.17
# No. Observations:                 235   AIC:                            -1744.
# Df Residuals:                     233   BIC:                            -1737.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0696      0.001     85.747      0.000       0.068       0.071
# instances_n     0.0062      0.000     54.148      0.000       0.006       0.006
# ==============================================================================
# Omnibus:                       26.000   Durbin-Watson:                   1.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.813
# Skew:                           0.665   Prob(JB):                     2.26e-09
# Kurtosis:                       4.516   Cond. No.                         15.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_latency` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.836
# Model:                            OLS   Adj. R-squared:                  0.835
# Method:                 Least Squares   F-statistic:                     1187.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           2.10e-93
# Time:                        15:49:10   Log-Likelihood:                 779.97
# No. Observations:                 235   AIC:                            -1556.
# Df Residuals:                     233   BIC:                            -1549.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0582      0.002     37.186      0.000       0.055       0.061
# cpu         7.292e-06   2.12e-07     34.449      0.000    6.88e-06    7.71e-06
# ==============================================================================
# Omnibus:                       28.312   Durbin-Watson:                   0.596
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.862
# Skew:                           0.865   Prob(JB):                     2.69e-08
# Kurtosis:                       3.753   Cond. No.                     2.02e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.02e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `memory`

# %%
results = fit_regression(data=df, formula='app_latency ~ memory')
draw_regression_graph(results, df, metric_name='app_latency', variable='memory')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.871
# Method:                 Least Squares   F-statistic:                     1579.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):          9.24e-106
# Time:                        15:49:10   Log-Likelihood:                 808.65
# No. Observations:                 235   AIC:                            -1613.
# Df Residuals:                     233   BIC:                            -1606.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1586      0.007    -23.545      0.000      -0.172      -0.145
# memory      5.205e-11   1.31e-12     39.738      0.000    4.95e-11    5.46e-11
# ==============================================================================
# Omnibus:                       36.510   Durbin-Watson:                   1.152
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               68.238
# Skew:                           0.807   Prob(JB):                     1.52e-15
# Kurtosis:                       5.090   Cond. No.                     6.82e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.82e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     1524.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):          3.63e-134
# Time:                        15:49:10   Log-Likelihood:                 878.86
# No. Observations:                 235   AIC:                            -1752.
# Df Residuals:                     232   BIC:                            -1741.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0729      0.001     54.861      0.000       0.070       0.075
# instances_n     0.0075      0.000     17.500      0.000       0.007       0.008
# cpu         -1.623e-06   5.28e-07     -3.073      0.002   -2.66e-06   -5.83e-07
# ==============================================================================
# Omnibus:                       22.102   Durbin-Watson:                   1.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.850
# Skew:                           0.543   Prob(JB):                     9.96e-09
# Kurtosis:                       4.607   Cond. No.                     2.66e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.66e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu` + `memory`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu + memory')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                     1012.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):          1.54e-132
# Time:                        15:49:10   Log-Likelihood:                 878.90
# No. Observations:                 235   AIC:                            -1750.
# Df Residuals:                     231   BIC:                            -1736.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0677      0.018      3.665      0.000       0.031       0.104
# instances_n     0.0074      0.001     12.822      0.000       0.006       0.009
# cpu         -1.655e-06   5.42e-07     -3.056      0.003   -2.72e-06   -5.88e-07
# memory       1.177e-12   4.21e-12      0.279      0.780   -7.13e-12    9.48e-12
# ==============================================================================
# Omnibus:                       21.509   Durbin-Watson:                   1.111
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.468
# Skew:                           0.534   Prob(JB):                     1.99e-08
# Kurtosis:                       4.576   Cond. No.                     2.51e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.51e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm

fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "memory", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     3117.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):          7.17e-137
# Time:                        15:49:12   Log-Likelihood:                -1877.8
# No. Observations:                 235   AIC:                             3760.
# Df Residuals:                     233   BIC:                             3767.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    2011.1317     98.907     20.333      0.000    1816.264    2205.999
# instances_n   785.1436     14.062     55.834      0.000     757.439     812.849
# ==============================================================================
# Omnibus:                       76.053   Durbin-Watson:                   0.517
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              269.950
# Skew:                          -1.314   Prob(JB):                     2.41e-59
# Kurtosis:                       7.545   Cond. No.                         15.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `memory` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='memory ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='memory', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 memory   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.944
# Method:                 Least Squares   F-statistic:                     3918.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):          1.03e-147
# Time:                        15:49:13   Log-Likelihood:                -4642.3
# No. Observations:                 235   AIC:                             9289.
# Df Residuals:                     233   BIC:                             9296.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    4.427e+09   1.27e+07    348.283      0.000     4.4e+09    4.45e+09
# instances_n  1.131e+08   1.81e+06     62.595      0.000     1.1e+08    1.17e+08
# ==============================================================================
# Omnibus:                        3.327   Durbin-Watson:                   1.753
# Prob(Omnibus):                  0.189   Jarque-Bera (JB):                3.630
# Skew:                           0.089   Prob(JB):                        0.163
# Kurtosis:                       3.583   Cond. No.                         15.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `memory` ~ `cpu`

# %%
results = fit_regression(data=df, formula='memory ~ cpu')
print(results.summary())
draw_regression_graph(results, df, metric_name='memory', variable='cpu')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 memory   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     2180.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):          2.97e-120
# Time:                        15:49:13   Log-Likelihood:                -4706.1
# No. Observations:                 235   AIC:                             9416.
# Df Residuals:                     233   BIC:                             9423.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.193e+09   2.15e+07    194.821      0.000    4.15e+09    4.24e+09
# cpu          1.36e+05   2912.363     46.688      0.000     1.3e+05    1.42e+05
# ==============================================================================
# Omnibus:                       47.724   Durbin-Watson:                   1.358
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              110.138
# Skew:                           0.945   Prob(JB):                     1.21e-24
# Kurtosis:                       5.770   Cond. No.                     2.02e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.02e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Linpack 12x20min

# %%
experiment_name = 'linpack_12x20'

exp_name, df = next(get_data_with_metrics(experiment_name, experiments_path, instances_n=12))

df.head()
# Out:
#   cbtool_time    cpu_time  app_latency  app_throughput     cpu        memory  \
# 0  1592311591  1592311594          NaN         33.3820  2035.0  4.546589e+09
# 1  1592311651  1592311654          NaN         33.3700  2034.0  4.547256e+09
# 2  1592311711  1592311715          NaN         33.3523  2034.0  4.545925e+09
# 3  1592311771  1592311775          NaN         32.2720  2057.0  4.546154e+09
# 4  1592311831  1592311836          NaN         33.1085  2044.0  4.545212e+09
#
#    instances_n
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ### `app_throughput` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n')
draw_regression_graph(results, df, metric_name='app_throughput', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.923
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     1796.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           5.21e-85
# Time:                        15:49:14   Log-Likelihood:                -326.28
# No. Observations:                 151   AIC:                             656.6
# Df Residuals:                     149   BIC:                             662.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      34.6673      0.328    105.597      0.000      34.019      35.316
# instances_n    -2.3729      0.056    -42.374      0.000      -2.484      -2.262
# ==============================================================================
# Omnibus:                        2.871   Durbin-Watson:                   1.290
# Prob(Omnibus):                  0.238   Jarque-Bera (JB):                2.908
# Skew:                          -0.325   Prob(JB):                        0.234
# Kurtosis:                       2.798   Cond. No.                         11.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_throughput` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ cpu')
draw_regression_graph(results, df, metric_name='app_throughput', variable='cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.924
# Method:                 Least Squares   F-statistic:                     1822.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           1.90e-85
# Time:                        15:49:14   Log-Likelihood:                -325.26
# No. Observations:                 151   AIC:                             654.5
# Df Residuals:                     149   BIC:                             660.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     38.5273      0.406     94.955      0.000      37.726      39.329
# cpu           -0.0021   4.98e-05    -42.685      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                        1.684   Durbin-Watson:                   1.562
# Prob(Omnibus):                  0.431   Jarque-Bera (JB):                1.606
# Skew:                          -0.250   Prob(JB):                        0.448
# Kurtosis:                       2.933   Cond. No.                     1.93e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.93e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_throughput` ~ `memory`

# %%
results = fit_regression(data=df, formula='app_throughput ~ memory')
draw_regression_graph(results, df, metric_name='app_throughput', variable='memory')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.846
# Model:                            OLS   Adj. R-squared:                  0.845
# Method:                 Least Squares   F-statistic:                     817.5
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           2.27e-62
# Time:                        15:49:14   Log-Likelihood:                -379.07
# No. Observations:                 151   AIC:                             762.1
# Df Residuals:                     149   BIC:                             768.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     75.0696      1.844     40.716      0.000      71.426      78.713
# memory     -9.568e-09   3.35e-10    -28.591      0.000   -1.02e-08   -8.91e-09
# ==============================================================================
# Omnibus:                        0.463   Durbin-Watson:                   1.172
# Prob(Omnibus):                  0.793   Jarque-Bera (JB):                0.200
# Skew:                          -0.059   Prob(JB):                        0.905
# Kurtosis:                       3.134   Cond. No.                     4.16e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.16e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_throughput` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     1293.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           1.84e-94
# Time:                        15:49:14   Log-Likelihood:                -300.02
# No. Observations:                 151   AIC:                             606.0
# Df Residuals:                     148   BIC:                             615.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      36.9478      0.401     92.050      0.000      36.155      37.741
# instances_n    -1.2008      0.157     -7.665      0.000      -1.510      -0.891
# cpu            -0.0011      0.000     -7.846      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                        3.221   Durbin-Watson:                   1.902
# Prob(Omnibus):                  0.200   Jarque-Bera (JB):                2.843
# Skew:                          -0.329   Prob(JB):                        0.241
# Kurtosis:                       3.137   Cond. No.                     2.30e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.3e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_throughput` ~ `instances_n` + `cpu` + `memory`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n + cpu + memory')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     858.3
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           6.47e-93
# Time:                        15:49:14   Log-Likelihood:                -299.87
# No. Observations:                 151   AIC:                             607.7
# Df Residuals:                     147   BIC:                             619.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      38.8270      3.483     11.149      0.000      31.944      45.710
# instances_n    -1.0820      0.269     -4.018      0.000      -1.614      -0.550
# cpu            -0.0011      0.000     -7.709      0.000      -0.001      -0.001
# memory      -4.256e-10   7.84e-10     -0.543      0.588   -1.97e-09    1.12e-09
# ==============================================================================
# Omnibus:                        3.131   Durbin-Watson:                   1.909
# Prob(Omnibus):                  0.209   Jarque-Bera (JB):                2.807
# Skew:                          -0.331   Prob(JB):                        0.246
# Kurtosis:                       3.094   Cond. No.                     1.32e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "memory", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.909
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     1491.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           1.68e-79
# Time:                        15:49:16   Log-Likelihood:                -1262.3
# No. Observations:                 151   AIC:                             2529.
# Df Residuals:                     149   BIC:                             2535.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    2070.8036    161.576     12.816      0.000    1751.527    2390.080
# instances_n  1064.2900     27.560     38.617      0.000    1009.831    1118.749
# ==============================================================================
# Omnibus:                        2.003   Durbin-Watson:                   0.276
# Prob(Omnibus):                  0.367   Jarque-Bera (JB):                1.615
# Skew:                          -0.239   Prob(JB):                        0.446
# Kurtosis:                       3.168   Cond. No.                         11.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
results = fit_regression(data=df, formula='memory ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='memory', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 memory   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     2003.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           2.72e-88
# Time:                        15:49:16   Log-Likelihood:                -3094.2
# No. Observations:                 151   AIC:                             6192.
# Df Residuals:                     149   BIC:                             6198.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    4.317e+09      3e+07    143.935      0.000    4.26e+09    4.38e+09
# instances_n   2.29e+08   5.12e+06     44.756      0.000    2.19e+08    2.39e+08
# ==============================================================================
# Omnibus:                       16.352   Durbin-Watson:                   1.468
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.125
# Skew:                           0.169   Prob(JB):                     6.50e-13
# Kurtosis:                       5.967   Cond. No.                         11.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
experiment_name = 'wrk_12x20'

exp_name, df = next(get_data_with_metrics(experiment_name, experiments_path, instances_n=12))

df.head()
# Out:
#   cbtool_time    cpu_time  app_latency  app_throughput     cpu        memory  \
# 0  1591802843  1591802848        15.24          8880.0  7167.0  4.690260e+09
# 1  1591802907  1591802908        10.08         20180.0  5906.0  4.676293e+09
# 2  1591802971  1591802969        20.20          5360.0  7869.0  4.687049e+09
# 3  1591803449  1591803453        21.11          5340.0  6597.0  4.683792e+09
# 4  1591803513  1591803514        10.05         20140.0  6163.0  4.669866e+09
#
#    instances_n
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     2273.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           1.65e-60
# Time:                        15:49:17   Log-Likelihood:                -264.11
# No. Observations:                  82   AIC:                             532.2
# Df Residuals:                      80   BIC:                             537.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      14.0505      1.468      9.574      0.000      11.130      16.971
# instances_n    10.1371      0.213     47.673      0.000       9.714      10.560
# ==============================================================================
# Omnibus:                        5.551   Durbin-Watson:                   1.279
# Prob(Omnibus):                  0.062   Jarque-Bera (JB):                5.251
# Skew:                          -0.619   Prob(JB):                       0.0724
# Kurtosis:                       3.059   Cond. No.                         15.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.716
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     201.8
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           1.39e-23
# Time:                        15:49:17   Log-Likelihood:                -351.11
# No. Observations:                  82   AIC:                             706.2
# Df Residuals:                      80   BIC:                             711.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -148.2236     15.911     -9.316      0.000    -179.888    -116.559
# cpu            0.0205      0.001     14.207      0.000       0.018       0.023
# ==============================================================================
# Omnibus:                        5.369   Durbin-Watson:                   0.492
# Prob(Omnibus):                  0.068   Jarque-Bera (JB):                5.421
# Skew:                           0.620   Prob(JB):                       0.0665
# Kurtosis:                       2.780   Cond. No.                     8.96e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.96e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
results = fit_regression(data=df, formula='app_latency ~ memory')
draw_regression_graph(results, df, metric_name='app_latency', variable='memory')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.633
# Model:                            OLS   Adj. R-squared:                  0.629
# Method:                 Least Squares   F-statistic:                     138.1
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           4.16e-19
# Time:                        15:49:18   Log-Likelihood:                -361.61
# No. Observations:                  82   AIC:                             727.2
# Df Residuals:                      80   BIC:                             732.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -586.1194     56.387    -10.395      0.000    -698.332    -473.907
# memory      1.296e-07    1.1e-08     11.754      0.000    1.08e-07    1.52e-07
# ==============================================================================
# Omnibus:                        6.913   Durbin-Watson:                   0.150
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                7.204
# Skew:                           0.706   Prob(JB):                       0.0273
# Kurtosis:                       2.663   Cond. No.                     1.30e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Wrk 12x20min

# %%
experiment_name = 'wrk_12x20'

exp_name, df = next(get_data_with_metrics(experiment_name, experiments_path, instances_n=12))

df.head()
# Out:
#   cbtool_time    cpu_time  app_latency  app_throughput     cpu        memory  \
# 0  1591802843  1591802848        15.24          8880.0  7167.0  4.690260e+09
# 1  1591802907  1591802908        10.08         20180.0  5906.0  4.676293e+09
# 2  1591802971  1591802969        20.20          5360.0  7869.0  4.687049e+09
# 3  1591803449  1591803453        21.11          5340.0  6597.0  4.683792e+09
# 4  1591803513  1591803514        10.05         20140.0  6163.0  4.669866e+09
#
#    instances_n
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ### `app_latency` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     2273.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           1.65e-60
# Time:                        15:49:18   Log-Likelihood:                -264.11
# No. Observations:                  82   AIC:                             532.2
# Df Residuals:                      80   BIC:                             537.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      14.0505      1.468      9.574      0.000      11.130      16.971
# instances_n    10.1371      0.213     47.673      0.000       9.714      10.560
# ==============================================================================
# Omnibus:                        5.551   Durbin-Watson:                   1.279
# Prob(Omnibus):                  0.062   Jarque-Bera (JB):                5.251
# Skew:                          -0.619   Prob(JB):                       0.0724
# Kurtosis:                       3.059   Cond. No.                         15.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_latency` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.716
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     201.8
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           1.39e-23
# Time:                        15:49:19   Log-Likelihood:                -351.11
# No. Observations:                  82   AIC:                             706.2
# Df Residuals:                      80   BIC:                             711.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -148.2236     15.911     -9.316      0.000    -179.888    -116.559
# cpu            0.0205      0.001     14.207      0.000       0.018       0.023
# ==============================================================================
# Omnibus:                        5.369   Durbin-Watson:                   0.492
# Prob(Omnibus):                  0.068   Jarque-Bera (JB):                5.421
# Skew:                           0.620   Prob(JB):                       0.0665
# Kurtosis:                       2.780   Cond. No.                     8.96e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.96e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `memory`

# %%
results = fit_regression(data=df, formula='app_latency ~ memory')
draw_regression_graph(results, df, metric_name='app_latency', variable='memory')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.633
# Model:                            OLS   Adj. R-squared:                  0.629
# Method:                 Least Squares   F-statistic:                     138.1
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           4.16e-19
# Time:                        15:49:19   Log-Likelihood:                -361.61
# No. Observations:                  82   AIC:                             727.2
# Df Residuals:                      80   BIC:                             732.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -586.1194     56.387    -10.395      0.000    -698.332    -473.907
# memory      1.296e-07    1.1e-08     11.754      0.000    1.08e-07    1.52e-07
# ==============================================================================
# Omnibus:                        6.913   Durbin-Watson:                   0.150
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                7.204
# Skew:                           0.706   Prob(JB):                       0.0273
# Kurtosis:                       2.663   Cond. No.                     1.30e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.978
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     1787.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           1.71e-66
# Time:                        15:49:19   Log-Likelihood:                -245.55
# No. Observations:                  82   AIC:                             497.1
# Df Residuals:                      79   BIC:                             504.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     -25.1343      5.946     -4.227      0.000     -36.969     -13.300
# instances_n     8.6491      0.279     30.949      0.000       8.093       9.205
# cpu             0.0044      0.001      6.724      0.000       0.003       0.006
# ==============================================================================
# Omnibus:                        5.587   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.061   Jarque-Bera (JB):                8.407
# Skew:                          -0.053   Prob(JB):                       0.0149
# Kurtosis:                       4.565   Cond. No.                     1.21e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu` + `memory`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu + memory')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     1344.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           4.95e-67
# Time:                        15:49:19   Log-Likelihood:                -240.18
# No. Observations:                  82   AIC:                             488.4
# Df Residuals:                      78   BIC:                             498.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     -88.9481     20.109     -4.423      0.000    -128.983     -48.914
# instances_n     8.5067      0.267     31.870      0.000       7.975       9.038
# cpu             0.0025      0.001      3.043      0.003       0.001       0.004
# memory       1.665e-08   5.04e-09      3.304      0.001    6.62e-09    2.67e-08
# ==============================================================================
# Omnibus:                       13.688   Durbin-Watson:                   2.248
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               27.129
# Skew:                           0.546   Prob(JB):                     1.29e-06
# Kurtosis:                       5.598   Cond. No.                     2.01e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.01e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm

fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "memory", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.627
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                     134.5
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           8.14e-19
# Time:                        15:49:21   Log-Likelihood:                -667.34
# No. Observations:                  82   AIC:                             1339.
# Df Residuals:                      80   BIC:                             1343.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    8875.9065    200.554     44.257      0.000    8476.791    9275.022
# instances_n   337.0491     29.058     11.599      0.000     279.221     394.877
# ==============================================================================
# Omnibus:                       44.204   Durbin-Watson:                   0.429
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              116.619
# Skew:                          -1.881   Prob(JB):                     4.75e-26
# Kurtosis:                       7.471   Cond. No.                         15.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `memory` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='memory ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='memory', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 memory   R-squared:                       0.535
# Model:                            OLS   Adj. R-squared:                  0.529
# Method:                 Least Squares   F-statistic:                     91.92
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           6.18e-15
# Time:                        15:49:21   Log-Likelihood:                -1653.1
# No. Observations:                  82   AIC:                             3310.
# Df Residuals:                      80   BIC:                             3315.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    4.826e+09   3.33e+07    144.777      0.000    4.76e+09    4.89e+09
# instances_n   4.63e+07   4.83e+06      9.588      0.000    3.67e+07    5.59e+07
# ==============================================================================
# Omnibus:                       17.405   Durbin-Watson:                   0.059
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                6.120
# Skew:                           0.393   Prob(JB):                       0.0469
# Kurtosis:                       1.917   Cond. No.                         15.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `memory` ~ `cpu`

# %%
results = fit_regression(data=df, formula='memory ~ cpu')
print(results.summary())
draw_regression_graph(results, df, metric_name='memory', variable='cpu')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 memory   R-squared:                       0.739
# Model:                            OLS   Adj. R-squared:                  0.736
# Method:                 Least Squares   F-statistic:                     226.8
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           4.61e-25
# Time:                        15:49:21   Log-Likelihood:                -1629.3
# No. Observations:                  82   AIC:                             3263.
# Df Residuals:                      80   BIC:                             3267.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    3.71e+09   9.36e+07     39.620      0.000    3.52e+09     3.9e+09
# cpu         1.279e+05   8494.531     15.059      0.000    1.11e+05    1.45e+05
# ==============================================================================
# Omnibus:                        2.770   Durbin-Watson:                   0.530
# Prob(Omnibus):                  0.250   Jarque-Bera (JB):                2.267
# Skew:                           0.278   Prob(JB):                        0.322
# Kurtosis:                       2.405   Cond. No.                     8.96e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.96e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
