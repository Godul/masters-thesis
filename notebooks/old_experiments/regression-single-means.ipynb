# %% [markdown]
# # Single linear regression

# %% [markdown]
# We have not many samples (6), so `statsmodels` will give us warnings. We turn them off.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Redis YCSB 6x10

# %%
from helpers.helpers_old import (
    get_means,
    fit_regression,
    draw_regression_graph,
)

experiments_path = '../../data'
experiment_name = 'redis_ycsb_6x10'

exp_name, df = next(get_means(experiment_name, experiments_path))
results = fit_regression(data=df, formula='app_latency ~ instances_n')
print(results.summary())
print(results.params)

for exp_name, df in get_means(experiment_name, experiments_path):
    results = fit_regression(data=df, formula='app_latency ~ instances_n')
    draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
# Out:
# /home/godul/.local/lib/python3.7/site-packages/statsmodels/stats/stattools.py:75: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   "samples were given." % int(n), ValueWarning)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     111.1
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           0.000458
# Time:                        15:47:27   Log-Likelihood:                 28.755
# No. Observations:                   6   AIC:                            -53.51
# Df Residuals:                       4   BIC:                            -53.93
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0690      0.002     30.169      0.000       0.063       0.075
# instances_n     0.0062      0.001     10.540      0.000       0.005       0.008
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.377
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.669
# Skew:                           0.788   Prob(JB):                        0.716
# Kurtosis:                       2.562   Cond. No.                         9.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept      0.069018
# instances_n    0.006191
# dtype: float64

# %% [markdown]
# ## Redis YCSB 12x10min

# %%
experiment_name = 'redis_ycsb_12x10'

for exp_name, df in get_means(experiment_name, experiments_path, instances_n=12):
    results = fit_regression(data=df, formula='app_latency ~ instances_n')
    draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     398.1
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           2.20e-09
# Time:                        15:47:28   Log-Likelihood:                 51.007
# No. Observations:                  12   AIC:                            -98.01
# Df Residuals:                      10   BIC:                            -97.04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0691      0.002     29.716      0.000       0.064       0.074
# instances_n     0.0063      0.000     19.951      0.000       0.006       0.007
# ==============================================================================
# Omnibus:                        1.037   Durbin-Watson:                   1.152
# Prob(Omnibus):                  0.595   Jarque-Bera (JB):                0.781
# Skew:                          -0.547   Prob(JB):                        0.677
# Kurtosis:                       2.398   Cond. No.                         15.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Linpack 6x10min

# %%
experiment_name = 'linpack_6x10'


for exp_name, df in get_means(experiment_name, experiments_path):    
    results = fit_regression(data=df, formula='app_throughput ~ instances_n')
    draw_regression_graph(results, df, metric_name='app_throughput', variable='instances_n')

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                     679.3
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           1.29e-05
# Time:                        15:47:29   Log-Likelihood:                -3.0053
# No. Observations:                   6   AIC:                             10.01
# Df Residuals:                       4   BIC:                             9.594
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      36.5480      0.455     80.278      0.000      35.284      37.812
# instances_n    -3.0470      0.117    -26.064      0.000      -3.372      -2.722
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.409
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.484
# Skew:                           0.645   Prob(JB):                        0.785
# Kurtosis:                       2.477   Cond. No.                         9.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /home/godul/.local/lib/python3.7/site-packages/statsmodels/stats/stattools.py:75: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   "samples were given." % int(n), ValueWarning)

# %% [markdown]
# ## Linpack 12x10min

# %%
experiment_name = 'linpack_12x10'


for exp_name, df in get_means(experiment_name, experiments_path, instances_n=12):    
    results = fit_regression(data=df, formula='app_throughput ~ instances_n')
    draw_regression_graph(results, df, metric_name='app_throughput', variable='instances_n')

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.959
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     231.1
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           3.07e-08
# Time:                        15:47:29   Log-Likelihood:                -22.310
# No. Observations:                  12   AIC:                             48.62
# Df Residuals:                      10   BIC:                             49.59
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      33.3713      1.047     31.870      0.000      31.038      35.704
# instances_n    -2.1630      0.142    -15.203      0.000      -2.480      -1.846
# ==============================================================================
# Omnibus:                        1.215   Durbin-Watson:                   0.422
# Prob(Omnibus):                  0.545   Jarque-Bera (JB):                0.723
# Skew:                           0.066   Prob(JB):                        0.696
# Kurtosis:                       1.804   Cond. No.                         15.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Hadoop

# %%
experiment_name = 'hadoop_6x10'

for exp_name, df in get_means(experiment_name, experiments_path):
    results = fit_regression(data=df, formula='app_throughput ~ instances_n')
    draw_regression_graph(results, df, metric_name='app_throughput', variable='instances_n')

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     95.82
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           0.000610
# Time:                        15:47:29   Log-Likelihood:                -53.858
# No. Observations:                   6   AIC:                             111.7
# Df Residuals:                       4   BIC:                             111.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    8.057e+04   2183.108     36.906      0.000    7.45e+04    8.66e+04
# instances_n -5487.3797    560.570     -9.789      0.001   -7043.773   -3930.987
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.144
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.148
# Skew:                           0.085   Prob(JB):                        0.929
# Kurtosis:                       2.249   Cond. No.                         9.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /home/godul/.local/lib/python3.7/site-packages/statsmodels/stats/stattools.py:75: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   "samples were given." % int(n), ValueWarning)

# %% [markdown]
# ## Wrk 6x10min

# %%
experiment_name = 'wrk_6x10'

for exp_name, df in get_means(experiment_name, experiments_path):
    results = fit_regression(data=df, formula='app_latency ~ instances_n')
    draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
    
print(results.summary())
# Out:
# /home/godul/.local/lib/python3.7/site-packages/statsmodels/stats/stattools.py:75: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   "samples were given." % int(n), ValueWarning)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     637.4
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           1.46e-05
# Time:                        15:47:29   Log-Likelihood:                -11.348
# No. Observations:                   6   AIC:                             26.70
# Df Residuals:                       4   BIC:                             26.28
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       7.7405      1.829      4.233      0.013       2.664      12.817
# instances_n    11.8536      0.470     25.246      0.000      10.550      13.157
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.599
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.327
# Skew:                          -0.216   Prob(JB):                        0.849
# Kurtosis:                       1.940   Cond. No.                         9.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Wrk 12x10min

# %%
experiment_name = 'wrk_12x10'

for exp_name, df in get_means(experiment_name, experiments_path, instances_n=12):
    results = fit_regression(data=df, formula='app_latency ~ instances_n')
    draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
    
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     1164.
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           1.11e-11
# Time:                        15:47:30   Log-Likelihood:                -31.006
# No. Observations:                  12   AIC:                             66.01
# Df Residuals:                      10   BIC:                             66.98
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      14.6473      2.161      6.778      0.000       9.832      19.463
# instances_n    10.0182      0.294     34.117      0.000       9.364      10.673
# ==============================================================================
# Omnibus:                        0.521   Durbin-Watson:                   0.353
# Prob(Omnibus):                  0.771   Jarque-Bera (JB):                0.560
# Skew:                          -0.244   Prob(JB):                        0.756
# Kurtosis:                       2.061   Cond. No.                         15.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
