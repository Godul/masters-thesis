# %% [markdown]
# # Best OS metrics
#
# We want to select potential candidates for features in our models from OS metrics. There are many of them (1962), so we need to do it automatically.
#
# We'll fit simple linear regression model on every metrics as a feature and comparing R-squared.
#
# We'll start with Redis YCSB vs Redis YCSB experiment.

# %%
import pandas as pd

from helpers.load_data import (
    get_data_with_metrics,
    get_experiments_paths,
    trim_experiment,
)
from helpers.regression import fit_regression

experiments_path = '../../data/basic'

# %%
def get_rsquared_for_features(df: pd.DataFrame, target: str, features: list):
    rsquared_list = []
    aic_list = []

    for i, feature in enumerate(features):
        try:
            results = fit_regression(data=df, formula=f'{target} ~ {feature}')
            rsquared_list.append((results.rsquared, feature))
            aic_list.append((results.aic, feature))
        except Exception as e:
            print(f'\nError on feature {feature}!')
            print(str(e))

        if (i + 1) % 20 == 0:
            print(f'{i+1}/{len(features)}, ', end='', flush=True)

    return rsquared_list, aic_list


def print_rsquared_list(rsquared_list, limit):
    rsquared_list.sort(reverse=True)

    for rsquared, feature in rsquared_list[:limit]:
        print(f'{rsquared:.6f} {feature}')
        

def print_aic_list(aic_list, limit):
    aic_list.sort(reverse=False)

    for aic, feature in aic_list[:limit]:
        print(f'{aic:.4f} {feature}')
        
def print_joint(rsquared_list, aic_list, limit):
    rsquared_list.sort(reverse=True)
    aic_list.sort(reverse=False)

    for i, (rsquared, feat_1) in enumerate(rsquared_list[:limit], 1):
        for j, (aic, feat_2) in enumerate(aic_list, 1):
            if feat_1 == feat_2:
#                 print(f'{i:02} | {rsquared:.4f} | {j:02} | {aic:.2f} | {feat_1}')
                print(f'{i} | {rsquared:.4f} | {aic:.2f} | {feat_1}')
                break

# %% [markdown]
# ## Redis YCSB vs Redis YCSB

# %%
instances_n=12
experiment_name='redis_ycsb_1_redis_ycsb_11'
perf_metric = 'app_latency'
path = get_experiments_paths(experiment_name, experiments_path)[0]
df = get_data_with_metrics(path, instances_n=instances_n, cpu_window=30)
df['time'] = pd.to_datetime(df['cbtool_time'], unit='s')
trim=8
df = trim_experiment(df, trim)

# %%
features = ['instances_n', 'cpu', 'memory'] + list(df.columns[9:-1])
rsquared_redis_ycsb, aic_redis_ycsb = get_rsquared_for_features(df, perf_metric, features)
# Out:
# 20/1615, 40/1615, 60/1615, 80/1615, 100/1615, 120/1615, 140/1615, 160/1615, 180/1615, 200/1615, 220/1615, 240/1615, 260/1615, 280/1615, 300/1615, 320/1615, 340/1615, 360/1615, 380/1615, 400/1615, 420/1615, 440/1615, 460/1615, 480/1615, 500/1615, 520/1615, 540/1615, 560/1615, 580/1615, 600/1615, 620/1615, 640/1615, 660/1615, 680/1615, 700/1615, 720/1615, 740/1615, 760/1615, 780/1615, 800/1615, 820/1615, 840/1615, 860/1615, 880/1615, 900/1615, 920/1615, 940/1615, 960/1615, 980/1615, 1000/1615, 1020/1615, 1040/1615, 1060/1615, 1080/1615, 1100/1615, 1120/1615, 1140/1615, 1160/1615, 1180/1615, 1200/1615, 1220/1615, 1240/1615, 1260/1615, 1280/1615, 1300/1615, 1320/1615, 1340/1615, 1360/1615, 1380/1615, 1400/1615, 1420/1615, 1440/1615, 1460/1615, 1480/1615, 1500/1615, 1520/1615, 1540/1615, 1560/1615, 1580/1615, 1600/1615,

# %%
print_joint(rsquared_redis_ycsb, aic_redis_ycsb, limit=30)
# Out:
# 1 | 0.9875 | -1632.21 | node_memory_Committed_AS_bytes
# 2 | 0.9870 | -1625.90 | instances_n
# 3 | 0.9864 | -1619.87 | node_memory_MemFree_bytes
# 4 | 0.9863 | -1618.54 | node_memory_SUnreclaim_bytes
# 5 | 0.9852 | -1607.11 | node_filesystem_free_bytes_device__dev_mapper_ubuntu__vg_ubuntu__lvfstype_ext4mountpoint___
# 6 | 0.9852 | -1607.11 | node_filesystem_avail_bytes_device__dev_mapper_ubuntu__vg_ubuntu__lvfstype_ext4mountpoint___
# 7 | 0.9850 | -1604.83 | node_cpu_seconds_total_cpu_6mode_iowait_
# 8 | 0.9846 | -1601.09 | node_memory_Cached_bytes
# 9 | 0.9844 | -1599.24 | node_cpu_seconds_total_cpu_11mode_iowait_
# 10 | 0.9841 | -1596.79 | node_cpu_seconds_total_cpu_14mode_iowait_
# 11 | 0.9841 | -1596.76 | node_memory_Buffers_bytes
# 12 | 0.9841 | -1596.48 | node_cpu_seconds_total_cpu_8mode_iowait_
# 13 | 0.9839 | -1594.70 | node_cpu_seconds_total_cpu_10mode_iowait_
# 14 | 0.9838 | -1593.60 | node_cpu_seconds_total_cpu_9mode_iowait_
# 15 | 0.9837 | -1592.72 | node_cpu_seconds_total_cpu_19mode_iowait_
# 16 | 0.9837 | -1592.44 | node_cpu_seconds_total_cpu_13mode_iowait_
# 17 | 0.9836 | -1592.09 | node_memory_Inactive_file_bytes
# 18 | 0.9836 | -1592.08 | node_memory_Inactive_bytes
# 19 | 0.9832 | -1588.37 | node_cpu_seconds_total_cpu_22mode_iowait_
# 20 | 0.9832 | -1588.19 | node_disk_io_time_seconds_total_device_dm_0_
# 21 | 0.9832 | -1588.16 | node_cpu_seconds_total_cpu_5mode_iowait_
# 22 | 0.9831 | -1587.50 | node_cpu_seconds_total_cpu_2mode_iowait_
# 23 | 0.9831 | -1587.20 | node_cpu_seconds_total_cpu_15mode_iowait_
# 24 | 0.9830 | -1586.97 | node_filesystem_files_free_device__dev_mapper_ubuntu__vg_ubuntu__lvfstype_ext4mountpoint___
# 25 | 0.9830 | -1586.97 | node_cpu_seconds_total_cpu_21mode_iowait_
# 26 | 0.9830 | -1586.58 | node_memory_MemAvailable_bytes
# 27 | 0.9830 | -1586.23 | node_cpu_seconds_total_cpu_4mode_iowait_
# 28 | 0.9829 | -1586.02 | node_cpu_seconds_total_cpu_17mode_iowait_
# 29 | 0.9829 | -1585.93 | node_disk_writes_completed_total_device_dm_0_
# 30 | 0.9828 | -1584.54 | node_network_transmit_bytes_total_device_cni0_

# %% [markdown]
# ## Linpack vs Linpack

# %%
instances_n=12
experiment_name='linpack_1_linpack_11'
perf_metric = 'app_throughput_inv'
path = get_experiments_paths(experiment_name, experiments_path)[0]
df = get_data_with_metrics(path, instances_n=instances_n, cpu_window=30)
df['time'] = pd.to_datetime(df['cbtool_time'], unit='s')
trim=5
df = trim_experiment(df, trim)

# %%
features = ['instances_n', 'cpu', 'memory'] + list(df.columns[9:-1])
rsquared_linpack, aic_linpack = get_rsquared_for_features(df, perf_metric, features)
# Out:
# 20/1953, 40/1953, 60/1953, 80/1953, 100/1953, 120/1953, 140/1953, 160/1953, 180/1953, 200/1953, 220/1953, 240/1953, 260/1953, 280/1953, 300/1953, 320/1953, 340/1953, 360/1953, 380/1953, 400/1953, 420/1953, 440/1953, 460/1953, 480/1953, 500/1953, 520/1953, 540/1953, 560/1953, 580/1953, 600/1953, 620/1953, 640/1953, 660/1953, 680/1953, 700/1953, 720/1953, 740/1953, 760/1953, 780/1953, 800/1953, 820/1953, 840/1953, 860/1953, 880/1953, 900/1953, 920/1953, 940/1953, 960/1953, 980/1953, 1000/1953, 1020/1953, 1040/1953, 1060/1953, 1080/1953, 1100/1953, 1120/1953, 1140/1953, 1160/1953, 1180/1953, 1200/1953, 1220/1953, 1240/1953, 1260/1953, 1280/1953, 1300/1953, 1320/1953, 1340/1953, 1360/1953, 1380/1953, 1400/1953, 1420/1953, 1440/1953, 1460/1953, 1480/1953, 1500/1953, 1520/1953, 1540/1953, 1560/1953, 1580/1953, 1600/1953, 1620/1953, 1640/1953, 1660/1953, 1680/1953, 1700/1953, 1720/1953, 1740/1953, 1760/1953, 1780/1953, 1800/1953, 1820/1953, 1840/1953, 1860/1953, 1880/1953, 1900/1953, 1920/1953, 1940/1953,

# %%
print_joint(rsquared_linpack, aic_linpack, limit=30)
# Out:
# 1 | 0.8834 | -1088.90 | node_pressure_io_waiting_seconds_total
# 2 | 0.8833 | -1088.83 | node_pressure_io_stalled_seconds_total
# 3 | 0.8718 | -1082.18 | node_cpu_seconds_total_cpu_18mode_iowait_
# 4 | 0.8645 | -1078.23 | node_cpu_seconds_total_cpu_17mode_iowait_
# 5 | 0.8550 | -1073.44 | node_netstat_Icmp6_OutMsgs
# 6 | 0.8514 | -1071.66 | node_cpu_seconds_total_cpu_15mode_iowait_
# 7 | 0.8501 | -1071.08 | node_memory_Active_anon_bytes
# 8 | 0.8501 | -1071.05 | node_memory_Active_bytes
# 9 | 0.8500 | -1071.03 | node_memory_AnonPages_bytes
# 10 | 0.8499 | -1070.97 | node_memory_MemAvailable_bytes
# 11 | 0.8498 | -1070.91 | node_memory_MemFree_bytes
# 12 | 0.8490 | -1070.53 | cpu
# 13 | 0.8486 | -1070.37 | node_memory_Committed_AS_bytes
# 14 | 0.8482 | -1070.15 | instances_n
# 15 | 0.8470 | -1069.62 | node_memory_PageTables_bytes
# 16 | 0.8467 | -1069.48 | node_memory_Inactive_anon_bytes
# 17 | 0.8464 | -1069.32 | node_cpu_seconds_total_cpu_23mode_iowait_
# 18 | 0.8455 | -1068.89 | node_cpu_seconds_total_cpu_7mode_iowait_
# 19 | 0.8453 | -1068.82 | node_filesystem_files_free_device__dev_mapper_ubuntu__vg_ubuntu__lvfstype_ext4mountpoint___
# 20 | 0.8438 | -1068.14 | node_cpu_seconds_total_cpu_19mode_iowait_
# 21 | 0.8433 | -1067.93 | node_filesystem_avail_bytes_device__dev_mapper_ubuntu__vg_ubuntu__lvfstype_ext4mountpoint___
# 22 | 0.8433 | -1067.93 | node_filesystem_free_bytes_device__dev_mapper_ubuntu__vg_ubuntu__lvfstype_ext4mountpoint___
# 23 | 0.8426 | -1067.59 | node_schedstat_waiting_seconds_total_cpu_10_
# 24 | 0.8418 | -1067.25 | node_cpu_seconds_total_cpu_20mode_iowait_
# 25 | 0.8415 | -1067.09 | node_sockstat_TCP_inuse
# 26 | 0.8414 | -1067.06 | node_cpu_seconds_total_cpu_3mode_iowait_
# 27 | 0.8410 | -1066.89 | node_memory_KernelStack_bytes
# 28 | 0.8395 | -1066.20 | node_memory_SReclaimable_bytes
# 29 | 0.8395 | -1066.20 | node_memory_KReclaimable_bytes
# 30 | 0.8394 | -1066.19 | node_memory_Cached_bytes

# %% [markdown]
# ## Sysbench vs Sysbench

# %%
instances_n=12
experiment_name='sysbench_1_sysbench_11'
perf_metric = 'app_latency'
path = get_experiments_paths(experiment_name, experiments_path)[0]
df = get_data_with_metrics(path, instances_n=instances_n, cpu_window=30)
df['time'] = pd.to_datetime(df['cbtool_time'], unit='s')

# %%
features = ['instances_n', 'cpu', 'memory'] + list(df.columns[9:-1])
rsquared_sysbench, aic_sysbench = get_rsquared_for_features(df, perf_metric, features)
# Out:
# 20/1954, 40/1954, 60/1954, 80/1954, 100/1954, 120/1954, 140/1954, 160/1954, 180/1954, 200/1954, 220/1954, 240/1954, 260/1954, 280/1954, 300/1954, 320/1954, 340/1954, 360/1954, 380/1954, 400/1954, 420/1954, 440/1954, 460/1954, 480/1954, 500/1954, 520/1954, 540/1954, 560/1954, 580/1954, 600/1954, 620/1954, 640/1954, 660/1954, 680/1954, 700/1954, 720/1954, 740/1954, 760/1954, 780/1954, 800/1954, 820/1954, 840/1954, 860/1954, 880/1954, 900/1954, 920/1954, 940/1954, 960/1954, 980/1954, 1000/1954, 1020/1954, 1040/1954, 1060/1954, 1080/1954, 1100/1954, 1120/1954, 1140/1954, 1160/1954, 1180/1954, 1200/1954, 1220/1954, 1240/1954, 1260/1954, 1280/1954, 1300/1954, 1320/1954, 1340/1954, 1360/1954, 1380/1954, 1400/1954, 1420/1954, 1440/1954, 1460/1954, 1480/1954, 1500/1954, 1520/1954, 1540/1954, 1560/1954, 1580/1954, 1600/1954, 1620/1954, 1640/1954, 1660/1954, 1680/1954, 1700/1954, 1720/1954, 1740/1954, 1760/1954, 1780/1954, 1800/1954, 1820/1954, 1840/1954, 1860/1954, 1880/1954, 1900/1954, 1920/1954, 1940/1954,

# %%
print_joint(rsquared_sysbench, aic_sysbench, limit=500)
# Out:
# 1 | 0.9437 | 2283.30 | node_netstat_Tcp_CurrEstab
# 2 | 0.9350 | 2332.39 | node_sockstat_sockets_used
# 3 | 0.9331 | 2341.94 | node_filefd_allocated
# 4 | 0.9318 | 2348.91 | node_sockstat_TCP_inuse
# 5 | 0.9277 | 2368.57 | node_memory_Inactive_anon_bytes
# 6 | 0.9222 | 2393.53 | node_filesystem_files_free_device_tmpfsfstype_tmpfsmountpoint__run_snapd_ns_
# 7 | 0.9222 | 2393.55 | node_filesystem_files_free_device_tmpfsfstype_tmpfsmountpoint__run_
# 8 | 0.9211 | 2398.37 | node_sockstat_UDP6_inuse
# 9 | 0.9197 | 2404.34 | node_load1
# 10 | 0.9185 | 2409.27 | node_memory_Shmem_bytes
# 11 | 0.9181 | 2411.20 | node_filesystem_free_bytes_device_tmpfsfstype_tmpfsmountpoint__run_snapd_ns_
# 12 | 0.9181 | 2411.20 | node_filesystem_free_bytes_device_tmpfsfstype_tmpfsmountpoint__run_
# 13 | 0.9181 | 2411.20 | node_filesystem_avail_bytes_device_tmpfsfstype_tmpfsmountpoint__run_snapd_ns_
# 14 | 0.9181 | 2411.20 | node_filesystem_avail_bytes_device_tmpfsfstype_tmpfsmountpoint__run_
# 15 | 0.9176 | 2413.26 | node_sockstat_TCP_alloc
# 16 | 0.9174 | 2414.00 | node_netstat_Icmp6_OutMsgs
# 17 | 0.9129 | 2431.97 | node_memory_VmallocUsed_bytes
# 18 | 0.9115 | 2437.55 | node_memory_KernelStack_bytes
# 19 | 0.9091 | 2446.74 | node_disk_read_time_seconds_total_device_sda_
# 20 | 0.9091 | 2446.78 | node_memory_PageTables_bytes
# 21 | 0.9076 | 2452.38 | node_pressure_io_waiting_seconds_total
# 22 | 0.9075 | 2452.79 | node_pressure_io_stalled_seconds_total
# 23 | 0.9014 | 2474.26 | node_disk_io_time_seconds_total_device_sda_
# 24 | 0.9014 | 2474.28 | node_disk_io_time_seconds_total_device_dm_0_
# 25 | 0.9013 | 2474.62 | node_nfsd_requests_total_method_Commitproto_4_
# 26 | 0.8988 | 2483.38 | node_nfs_requests_total_method_Commitproto_4_
# 27 | 0.8983 | 2484.96 | node_disk_reads_completed_total_device_dm_0_
# 28 | 0.8979 | 2486.44 | node_filesystem_files_free_device__dev_mapper_ubuntu__vg_ubuntu__lvfstype_ext4mountpoint___
# 29 | 0.8974 | 2487.91 | node_scrape_collector_duration_seconds_collector_netclass_
# 30 | 0.8973 | 2488.45 | node_cpu_seconds_total_cpu_12mode_idle_
# 31 | 0.8972 | 2488.59 | node_netstat_Udp_OutDatagrams
# 32 | 0.8972 | 2488.65 | node_cpu_seconds_total_cpu_8mode_idle_
# 33 | 0.8972 | 2488.65 | node_network_transmit_bytes_total_device_vethe9a8e778_
# 34 | 0.8972 | 2488.75 | node_cpu_seconds_total_cpu_0mode_idle_
# 35 | 0.8971 | 2488.91 | node_cpu_seconds_total_cpu_11mode_idle_
# 36 | 0.8971 | 2488.98 | node_cpu_seconds_total_cpu_4mode_idle_
# 37 | 0.8971 | 2489.04 | node_cpu_seconds_total_cpu_15mode_idle_
# 38 | 0.8971 | 2489.09 | node_cpu_seconds_total_cpu_23mode_idle_
# 39 | 0.8971 | 2489.11 | node_cpu_seconds_total_cpu_1mode_idle_
# 40 | 0.8970 | 2489.21 | node_cpu_seconds_total_cpu_3mode_idle_
# 41 | 0.8970 | 2489.23 | node_cpu_seconds_total_cpu_6mode_idle_
# 42 | 0.8970 | 2489.30 | node_cpu_seconds_total_cpu_16mode_idle_
# 43 | 0.8970 | 2489.32 | node_cpu_seconds_total_cpu_20mode_idle_
# 44 | 0.8970 | 2489.34 | node_cpu_seconds_total_cpu_7mode_idle_
# 45 | 0.8970 | 2489.36 | node_cpu_seconds_total_cpu_19mode_idle_
# 46 | 0.8970 | 2489.37 | node_load5
# 47 | 0.8970 | 2489.44 | node_cpu_seconds_total_cpu_13mode_idle_
# 48 | 0.8969 | 2489.52 | node_cpu_seconds_total_cpu_9mode_idle_
# 49 | 0.8969 | 2489.54 | node_cpu_seconds_total_cpu_14mode_idle_
# 50 | 0.8969 | 2489.62 | node_cpu_seconds_total_cpu_5mode_idle_
# 51 | 0.8969 | 2489.67 | node_cpu_seconds_total_cpu_10mode_idle_
# 52 | 0.8969 | 2489.69 | node_cpu_seconds_total_cpu_21mode_idle_
# 53 | 0.8969 | 2489.79 | node_cpu_seconds_total_cpu_17mode_idle_
# 54 | 0.8968 | 2490.00 | node_network_transmit_packets_total_device_vethe9a8e778_
# 55 | 0.8968 | 2490.05 | node_cpu_seconds_total_cpu_18mode_idle_
# 56 | 0.8967 | 2490.14 | node_cpu_seconds_total_cpu_2mode_idle_
# 57 | 0.8967 | 2490.28 | node_cpu_seconds_total_cpu_22mode_idle_
# 58 | 0.8960 | 2492.67 | node_network_transmit_packets_total_device_veth351a4b21_
# 59 | 0.8956 | 2493.83 | node_network_receive_packets_total_device_vethe9a8e778_
# 60 | 0.8956 | 2494.06 | node_network_receive_bytes_total_device_vethe9a8e778_
# 61 | 0.8947 | 2496.84 | node_memory_Buffers_bytes
# 62 | 0.8941 | 2498.68 | promhttp_metric_handler_requests_total_code_200_
# 63 | 0.8939 | 2499.36 | node_nfs_requests_total_method_Writeproto_4_
# 64 | 0.8938 | 2499.73 | node_nfsd_requests_total_method_GetAttrproto_4_
# 65 | 0.8934 | 2500.86 | node_network_transmit_packets_total_device_vethc8462659_
# 66 | 0.8934 | 2500.88 | node_network_transmit_bytes_total_device_vethc8462659_
# 67 | 0.8934 | 2500.95 | node_network_transmit_bytes_total_device_veth61936ee7_
# 68 | 0.8934 | 2500.96 | node_network_receive_bytes_total_device_vethc8462659_
# 69 | 0.8934 | 2500.98 | node_network_receive_packets_total_device_vethc8462659_
# 70 | 0.8934 | 2501.04 | node_network_receive_packets_total_device_veth61936ee7_
# 71 | 0.8934 | 2501.10 | node_network_transmit_packets_total_device_veth61936ee7_
# 72 | 0.8934 | 2501.12 | go_memstats_last_gc_time_seconds
# 73 | 0.8934 | 2501.15 | node_time_seconds
# 74 | 0.8933 | 2501.19 | node_network_receive_bytes_total_device_veth61936ee7_
# 75 | 0.8931 | 2502.13 | node_network_receive_bytes_total_device_eno1_
# 76 | 0.8930 | 2502.33 | node_network_receive_packets_total_device_eno1_
# 77 | 0.8929 | 2502.75 | node_network_receive_packets_total_device_veth351a4b21_
# 78 | 0.8927 | 2503.18 | node_nfsd_requests_total_method_PutFHproto_4_
# 79 | 0.8927 | 2503.22 | node_nfs_rpcs_total
# 80 | 0.8927 | 2503.24 | node_nfs_rpc_authentication_refreshes_total
# 81 | 0.8927 | 2503.24 | node_nfsd_reply_cache_nocache_total
# 82 | 0.8927 | 2503.24 | node_nfsd_packets_total_proto_tcp_
# 83 | 0.8927 | 2503.24 | node_nfsd_server_rpcs_total
# 84 | 0.8926 | 2503.67 | node_network_transmit_bytes_total_device_veth351a4b21_
# 85 | 0.8926 | 2503.69 | node_network_receive_bytes_total_device_veth351a4b21_
# 86 | 0.8925 | 2503.78 | node_netstat_Tcp_ActiveOpens
# 87 | 0.8920 | 2505.51 | node_nfs_requests_total_method_Setattrproto_4_
# 88 | 0.8919 | 2505.68 | node_nfsd_requests_total_method_SetAttrproto_4_
# 89 | 0.8919 | 2505.81 | node_nfsd_requests_total_method_Renameproto_4_
# 90 | 0.8919 | 2505.81 | node_nfsd_requests_total_method_Lookupproto_4_
# 91 | 0.8919 | 2505.81 | node_nfs_requests_total_method_Lookupproto_4_
# 92 | 0.8919 | 2505.81 | node_nfsd_requests_total_method_SaveFHproto_4_
# 93 | 0.8919 | 2505.81 | node_nfs_requests_total_method_Renameproto_4_
# 94 | 0.8914 | 2507.37 | node_memory_Inactive_bytes
# 95 | 0.8914 | 2507.38 | node_netstat_Ip6_OutOctets
# 96 | 0.8914 | 2507.39 | node_memory_Inactive_file_bytes
# 97 | 0.8914 | 2507.43 | node_netstat_Ip6_InOctets
# 98 | 0.8912 | 2508.11 | node_memory_SUnreclaim_bytes
# 99 | 0.8911 | 2508.22 | node_nfsd_requests_total_method_GetFHproto_4_
# 100 | 0.8910 | 2508.59 | node_memory_Slab_bytes
# 101 | 0.8908 | 2509.22 | node_memory_Cached_bytes
# 102 | 0.8907 | 2509.41 | go_gc_duration_seconds_sum
# 103 | 0.8907 | 2509.62 | node_memory_SReclaimable_bytes
# 104 | 0.8907 | 2509.62 | node_memory_KReclaimable_bytes
# 105 | 0.8906 | 2509.84 | node_network_transmit_packets_total_device_eno1_
# 106 | 0.8906 | 2509.91 | node_netstat_Udp_NoPorts
# 107 | 0.8904 | 2510.48 | process_cpu_seconds_total
# 108 | 0.8904 | 2510.62 | go_memstats_gc_cpu_fraction
# 109 | 0.8903 | 2510.65 | node_network_receive_packets_total_device_veth614c7ad9_
# 110 | 0.8901 | 2511.46 | node_network_receive_multicast_total_device_eno1_
# 111 | 0.8901 | 2511.52 | node_nfs_requests_total_method_Getattrproto_4_
# 112 | 0.8900 | 2511.75 | node_netstat_Icmp_OutMsgs
# 113 | 0.8898 | 2512.35 | node_network_receive_bytes_total_device_vethc0ba428f_
# 114 | 0.8894 | 2513.51 | node_filesystem_free_bytes_device__dev_mapper_ubuntu__vg_ubuntu__lvfstype_ext4mountpoint___
# 115 | 0.8894 | 2513.51 | node_filesystem_avail_bytes_device__dev_mapper_ubuntu__vg_ubuntu__lvfstype_ext4mountpoint___
# 116 | 0.8893 | 2513.88 | node_network_transmit_packets_total_device_vetha9f6e9b3_
# 117 | 0.8891 | 2514.64 | node_disk_writes_completed_total_device_sda_
# 118 | 0.8889 | 2515.02 | node_network_transmit_packets_total_device_lo_
# 119 | 0.8889 | 2515.02 | node_network_receive_packets_total_device_lo_
# 120 | 0.8887 | 2515.88 | node_network_receive_packets_total_device_vetha9f6e9b3_
# 121 | 0.8886 | 2515.98 | node_network_transmit_packets_total_device_veth614c7ad9_
# 122 | 0.8884 | 2516.75 | node_nfs_requests_total_method_Openproto_4_
# 123 | 0.8867 | 2521.71 | go_memstats_alloc_bytes_total
# 124 | 0.8866 | 2522.19 | node_disk_read_time_seconds_total_device_dm_0_
# 125 | 0.8858 | 2524.41 | node_nfsd_requests_total_method_Openproto_4_
# 126 | 0.8854 | 2525.68 | node_network_transmit_packets_total_device_vethc0ba428f_
# 127 | 0.8845 | 2528.24 | node_network_receive_packets_total_device_vethc0ba428f_
# 128 | 0.8834 | 2531.58 | node_memory_MemFree_bytes
# 129 | 0.8822 | 2535.10 | node_nfsd_requests_total_method_Accessproto_4_
# 130 | 0.8812 | 2538.02 | go_memstats_mallocs_total
# 131 | 0.8812 | 2538.02 | go_memstats_frees_total
# 132 | 0.8799 | 2541.81 | node_nfsd_disk_bytes_written_total
# 133 | 0.8797 | 2542.36 | node_memory_Active_file_bytes
# 134 | 0.8794 | 2543.21 | node_network_transmit_bytes_total_device_lo_
# 135 | 0.8794 | 2543.21 | node_network_receive_bytes_total_device_lo_
# 136 | 0.8789 | 2544.42 | node_netstat_Tcp_OutSegs
# 137 | 0.8781 | 2546.72 | node_netstat_IpExt_InOctets
# 138 | 0.8772 | 2549.30 | node_memory_Committed_AS_bytes
# 139 | 0.8769 | 2549.98 | node_nfsd_requests_total_method_Closeproto_4_
# 140 | 0.8769 | 2549.98 | node_nfs_requests_total_method_Closeproto_4_
# 141 | 0.8766 | 2550.91 | node_disk_reads_merged_total_device_sda_
# 142 | 0.8766 | 2551.01 | node_disk_writes_completed_total_device_dm_0_
# 143 | 0.8755 | 2553.85 | node_netstat_Tcp_InSegs
# 144 | 0.8749 | 2555.52 | node_memory_MemAvailable_bytes
# 145 | 0.8746 | 2556.38 | node_cpu_seconds_total_cpu_22mode_iowait_
# 146 | 0.8732 | 2560.10 | node_memory_Active_bytes
# 147 | 0.8732 | 2560.28 | node_cpu_seconds_total_cpu_0mode_softirq_
# 148 | 0.8729 | 2561.00 | node_memory_Active_anon_bytes
# 149 | 0.8728 | 2561.37 | node_memory_AnonPages_bytes
# 150 | 0.8721 | 2563.09 | memory
# 151 | 0.8721 | 2563.26 | node_network_receive_bytes_total_device_veth614c7ad9_
# 152 | 0.8719 | 2563.72 | node_cpu_seconds_total_cpu_18mode_iowait_
# 153 | 0.8718 | 2563.85 | node_schedstat_timeslices_total_cpu_1_
# 154 | 0.8713 | 2565.17 | node_schedstat_timeslices_total_cpu_14_
# 155 | 0.8713 | 2565.18 | node_schedstat_timeslices_total_cpu_23_
# 156 | 0.8713 | 2565.36 | node_schedstat_timeslices_total_cpu_10_
# 157 | 0.8712 | 2565.64 | node_schedstat_timeslices_total_cpu_5_
# 158 | 0.8711 | 2565.88 | node_schedstat_timeslices_total_cpu_16_
# 159 | 0.8711 | 2565.90 | node_schedstat_timeslices_total_cpu_2_
# 160 | 0.8710 | 2565.98 | node_nfsd_requests_total_method_ReadDirproto_4_
# 161 | 0.8710 | 2565.98 | node_nfs_requests_total_method_ReadDirproto_4_
# 162 | 0.8710 | 2565.99 | node_cpu_seconds_total_cpu_2mode_iowait_
# 163 | 0.8710 | 2566.07 | node_cpu_seconds_total_cpu_7mode_iowait_
# 164 | 0.8710 | 2566.10 | node_schedstat_timeslices_total_cpu_4_
# 165 | 0.8710 | 2566.17 | node_schedstat_timeslices_total_cpu_9_
# 166 | 0.8706 | 2567.01 | node_cpu_seconds_total_cpu_17mode_iowait_
# 167 | 0.8706 | 2567.04 | instances_n
# 168 | 0.8706 | 2567.09 | node_schedstat_timeslices_total_cpu_22_
# 169 | 0.8705 | 2567.26 | node_context_switches_total
# 170 | 0.8705 | 2567.29 | node_schedstat_timeslices_total_cpu_6_
# 171 | 0.8703 | 2567.79 | node_schedstat_timeslices_total_cpu_21_
# 172 | 0.8703 | 2567.83 | node_schedstat_timeslices_total_cpu_7_
# 173 | 0.8703 | 2567.83 | node_schedstat_timeslices_total_cpu_8_
# 174 | 0.8703 | 2567.91 | node_schedstat_timeslices_total_cpu_11_
# 175 | 0.8703 | 2567.96 | node_schedstat_timeslices_total_cpu_17_
# 176 | 0.8701 | 2568.39 | node_schedstat_timeslices_total_cpu_19_
# 177 | 0.8698 | 2569.15 | node_schedstat_timeslices_total_cpu_3_
# 178 | 0.8698 | 2569.32 | node_schedstat_timeslices_total_cpu_13_
# 179 | 0.8697 | 2569.40 | node_intr_total
# 180 | 0.8697 | 2569.41 | node_schedstat_timeslices_total_cpu_12_
# 181 | 0.8697 | 2569.46 | node_schedstat_timeslices_total_cpu_20_
# 182 | 0.8697 | 2569.56 | node_schedstat_timeslices_total_cpu_18_
# 183 | 0.8695 | 2569.91 | node_schedstat_timeslices_total_cpu_0_
# 184 | 0.8693 | 2570.45 | node_schedstat_timeslices_total_cpu_15_
# 185 | 0.8693 | 2570.54 | node_cpu_seconds_total_cpu_19mode_iowait_
# 186 | 0.8691 | 2571.16 | node_disk_write_time_seconds_total_device_sda_
# 187 | 0.8689 | 2571.62 | node_cpu_seconds_total_cpu_10mode_iowait_
# 188 | 0.8687 | 2572.07 | node_cpu_seconds_total_cpu_9mode_iowait_
# 189 | 0.8687 | 2572.12 | node_cpu_seconds_total_cpu_21mode_iowait_
# 190 | 0.8686 | 2572.24 | node_nf_conntrack_entries
# 191 | 0.8681 | 2573.69 | node_cpu_seconds_total_cpu_5mode_iowait_
# 192 | 0.8679 | 2574.12 | node_network_transmit_drop_total_device_flannel1_
# 193 | 0.8677 | 2574.60 | node_cpu_seconds_total_cpu_13mode_iowait_
# 194 | 0.8674 | 2575.43 | node_network_transmit_bytes_total_device_veth614c7ad9_
# 195 | 0.8673 | 2575.71 | node_cpu_seconds_total_cpu_15mode_iowait_
# 196 | 0.8666 | 2577.45 | node_disk_io_time_weighted_seconds_total_device_sda_
# 197 | 0.8666 | 2577.46 | node_cpu_seconds_total_cpu_4mode_iowait_
# 198 | 0.8665 | 2577.88 | node_schedstat_waiting_seconds_total_cpu_4_
# 199 | 0.8663 | 2578.23 | node_cpu_seconds_total_cpu_20mode_iowait_
# 200 | 0.8663 | 2578.35 | node_cpu_seconds_total_cpu_6mode_iowait_
# 201 | 0.8660 | 2579.05 | node_schedstat_waiting_seconds_total_cpu_9_
# 202 | 0.8659 | 2579.32 | node_network_transmit_bytes_total_device_tun1_
# 203 | 0.8659 | 2579.32 | node_network_transmit_packets_total_device_tun1_
# 204 | 0.8657 | 2579.81 | node_vmstat_pgpgin
# 205 | 0.8655 | 2580.28 | node_pressure_cpu_waiting_seconds_total
# 206 | 0.8654 | 2580.53 | node_schedstat_waiting_seconds_total_cpu_16_
# 207 | 0.8650 | 2581.65 | node_cpu_seconds_total_cpu_8mode_iowait_
# 208 | 0.8649 | 2581.78 | node_cpu_seconds_total_cpu_14mode_iowait_
# 209 | 0.8649 | 2581.89 | node_cpu_seconds_total_cpu_3mode_iowait_
# 210 | 0.8646 | 2582.49 | node_cpu_seconds_total_cpu_23mode_iowait_
# 211 | 0.8644 | 2583.13 | node_cpu_seconds_total_cpu_1mode_iowait_
# 212 | 0.8642 | 2583.58 | node_schedstat_waiting_seconds_total_cpu_1_
# 213 | 0.8635 | 2585.31 | node_schedstat_waiting_seconds_total_cpu_11_
# 214 | 0.8634 | 2585.54 | node_cpu_seconds_total_cpu_16mode_iowait_
# 215 | 0.8630 | 2586.58 | node_cpu_seconds_total_cpu_11mode_iowait_
# 216 | 0.8627 | 2587.21 | node_disk_io_time_weighted_seconds_total_device_dm_0_
# 217 | 0.8627 | 2587.42 | node_disk_write_time_seconds_total_device_dm_0_
# 218 | 0.8626 | 2587.66 | node_network_transmit_bytes_total_device_vetha9f6e9b3_
# 219 | 0.8620 | 2588.95 | node_disk_writes_merged_total_device_sda_
# 220 | 0.8619 | 2589.21 | node_cpu_seconds_total_cpu_12mode_iowait_
# 221 | 0.8606 | 2592.39 | node_cpu_seconds_total_cpu_0mode_iowait_
# 222 | 0.8605 | 2592.72 | node_arp_entries_device_cni0_
# 223 | 0.8605 | 2592.77 | node_network_receive_bytes_total_device_vetha9f6e9b3_
# 224 | 0.8602 | 2593.56 | node_network_transmit_bytes_total_device_cni0_
# 225 | 0.8597 | 2594.68 | node_vmstat_pgpgout
# 226 | 0.8570 | 2601.16 | node_schedstat_waiting_seconds_total_cpu_3_
# 227 | 0.8569 | 2601.38 | node_schedstat_waiting_seconds_total_cpu_13_
# 228 | 0.8569 | 2601.44 | node_network_transmit_bytes_total_device_vethc0ba428f_
# 229 | 0.8566 | 2602.14 | node_schedstat_waiting_seconds_total_cpu_15_
# 230 | 0.8562 | 2603.17 | node_schedstat_waiting_seconds_total_cpu_12_
# 231 | 0.8561 | 2603.22 | node_schedstat_waiting_seconds_total_cpu_8_
# 232 | 0.8555 | 2604.78 | node_schedstat_waiting_seconds_total_cpu_10_
# 233 | 0.8549 | 2606.16 | node_nfs_requests_total_method_OpenNoattrproto_4_
# 234 | 0.8535 | 2609.47 | node_schedstat_waiting_seconds_total_cpu_19_
# 235 | 0.8535 | 2609.54 | node_softnet_processed_total_cpu_4_
# 236 | 0.8530 | 2610.67 | node_schedstat_waiting_seconds_total_cpu_18_
# 237 | 0.8526 | 2611.59 | node_netstat_Icmp_InMsgs
# 238 | 0.8516 | 2613.92 | node_schedstat_waiting_seconds_total_cpu_7_
# 239 | 0.8512 | 2614.65 | node_schedstat_waiting_seconds_total_cpu_2_
# 240 | 0.8510 | 2615.27 | node_schedstat_waiting_seconds_total_cpu_5_
# 241 | 0.8509 | 2615.33 | node_schedstat_waiting_seconds_total_cpu_6_
# 242 | 0.8500 | 2617.46 | node_schedstat_waiting_seconds_total_cpu_22_
# 243 | 0.8493 | 2619.01 | node_schedstat_waiting_seconds_total_cpu_14_
# 244 | 0.8492 | 2619.24 | node_cpu_seconds_total_cpu_2mode_user_
# 245 | 0.8486 | 2620.56 | node_softnet_processed_total_cpu_11_
# 246 | 0.8485 | 2620.77 | node_schedstat_waiting_seconds_total_cpu_23_
# 247 | 0.8483 | 2621.45 | node_schedstat_waiting_seconds_total_cpu_20_
# 248 | 0.8481 | 2621.73 | node_schedstat_waiting_seconds_total_cpu_21_
# 249 | 0.8480 | 2621.93 | node_cpu_seconds_total_cpu_3mode_user_
# 250 | 0.8480 | 2622.10 | node_softnet_processed_total_cpu_5_
# 251 | 0.8479 | 2622.33 | node_cpu_seconds_total_cpu_9mode_user_
# 252 | 0.8475 | 2623.20 | node_softnet_processed_total_cpu_10_
# 253 | 0.8473 | 2623.68 | node_cpu_seconds_total_cpu_10mode_user_
# 254 | 0.8470 | 2624.25 | node_cpu_seconds_total_cpu_16mode_user_
# 255 | 0.8470 | 2624.32 | node_softnet_processed_total_cpu_8_
# 256 | 0.8469 | 2624.48 | node_cpu_seconds_total_cpu_5mode_user_
# 257 | 0.8468 | 2624.66 | node_cpu_seconds_total_cpu_14mode_user_
# 258 | 0.8465 | 2625.27 | node_network_transmit_packets_total_device_tun0_
# 259 | 0.8465 | 2625.38 | node_cpu_seconds_total_cpu_19mode_user_
# 260 | 0.8462 | 2626.00 | node_softnet_processed_total_cpu_2_
# 261 | 0.8462 | 2626.08 | node_cpu_seconds_total_cpu_8mode_user_
# 262 | 0.8462 | 2626.10 | node_cpu_seconds_total_cpu_20mode_user_
# 263 | 0.8460 | 2626.45 | node_softnet_processed_total_cpu_21_
# 264 | 0.8460 | 2626.54 | node_softnet_processed_total_cpu_9_
# 265 | 0.8458 | 2626.92 | node_cpu_seconds_total_cpu_11mode_user_
# 266 | 0.8457 | 2627.07 | node_cpu_seconds_total_cpu_23mode_user_
# 267 | 0.8456 | 2627.29 | node_cpu_seconds_total_cpu_1mode_softirq_
# 268 | 0.8456 | 2627.45 | node_cpu_seconds_total_cpu_17mode_user_
# 269 | 0.8455 | 2627.54 | node_cpu_seconds_total_cpu_12mode_user_
# 270 | 0.8455 | 2627.63 | node_cpu_seconds_total_cpu_18mode_user_
# 271 | 0.8454 | 2627.81 | node_softnet_processed_total_cpu_22_
# 272 | 0.8454 | 2627.83 | node_softnet_processed_total_cpu_13_
# 273 | 0.8453 | 2627.94 | node_softnet_processed_total_cpu_14_
# 274 | 0.8453 | 2628.03 | node_softnet_processed_total_cpu_3_
# 275 | 0.8452 | 2628.24 | node_softnet_processed_total_cpu_1_
# 276 | 0.8451 | 2628.47 | node_softnet_processed_total_cpu_15_
# 277 | 0.8451 | 2628.55 | node_cpu_seconds_total_cpu_6mode_user_
# 278 | 0.8450 | 2628.61 | node_cpu_seconds_total_cpu_13mode_user_
# 279 | 0.8450 | 2628.64 | node_cpu_seconds_total_cpu_4mode_user_
# 280 | 0.8450 | 2628.70 | node_scrape_collector_duration_seconds_collector_filesystem_
# 281 | 0.8449 | 2629.00 | node_cpu_seconds_total_cpu_21mode_user_
# 282 | 0.8448 | 2629.04 | node_softnet_processed_total_cpu_23_
# 283 | 0.8448 | 2629.15 | node_cpu_seconds_total_cpu_15mode_user_
# 284 | 0.8446 | 2629.51 | node_schedstat_running_seconds_total_cpu_2_
# 285 | 0.8445 | 2629.75 | node_cpu_seconds_total_cpu_22mode_user_
# 286 | 0.8444 | 2629.99 | node_softnet_processed_total_cpu_19_
# 287 | 0.8438 | 2631.29 | node_schedstat_running_seconds_total_cpu_14_
# 288 | 0.8438 | 2631.33 | node_schedstat_running_seconds_total_cpu_3_
# 289 | 0.8437 | 2631.60 | node_softnet_processed_total_cpu_6_
# 290 | 0.8436 | 2631.68 | node_schedstat_running_seconds_total_cpu_16_
# 291 | 0.8433 | 2632.46 | node_softnet_processed_total_cpu_7_
# 292 | 0.8432 | 2632.62 | node_softnet_processed_total_cpu_18_
# 293 | 0.8430 | 2632.96 | node_schedstat_running_seconds_total_cpu_11_
# 294 | 0.8430 | 2633.02 | node_cpu_seconds_total_cpu_1mode_user_
# 295 | 0.8430 | 2633.14 | node_schedstat_running_seconds_total_cpu_10_
# 296 | 0.8429 | 2633.16 | node_schedstat_running_seconds_total_cpu_20_
# 297 | 0.8426 | 2633.81 | node_cpu_seconds_total_cpu_0mode_user_
# 298 | 0.8426 | 2634.00 | node_schedstat_running_seconds_total_cpu_9_
# 299 | 0.8425 | 2634.05 | node_softnet_processed_total_cpu_12_
# 300 | 0.8425 | 2634.07 | node_schedstat_running_seconds_total_cpu_13_
# 301 | 0.8425 | 2634.07 | node_softnet_processed_total_cpu_20_
# 302 | 0.8424 | 2634.28 | node_schedstat_running_seconds_total_cpu_6_
# 303 | 0.8424 | 2634.32 | node_schedstat_running_seconds_total_cpu_8_
# 304 | 0.8424 | 2634.35 | node_schedstat_running_seconds_total_cpu_19_
# 305 | 0.8423 | 2634.54 | node_schedstat_running_seconds_total_cpu_5_
# 306 | 0.8422 | 2634.83 | node_cpu_seconds_total_cpu_7mode_user_
# 307 | 0.8421 | 2635.00 | node_schedstat_running_seconds_total_cpu_18_
# 308 | 0.8421 | 2635.09 | node_softnet_processed_total_cpu_0_
# 309 | 0.8420 | 2635.28 | node_schedstat_running_seconds_total_cpu_15_
# 310 | 0.8418 | 2635.74 | node_schedstat_running_seconds_total_cpu_4_
# 311 | 0.8417 | 2635.92 | node_schedstat_running_seconds_total_cpu_12_
# 312 | 0.8416 | 2636.02 | node_schedstat_running_seconds_total_cpu_17_
# 313 | 0.8414 | 2636.46 | node_softnet_processed_total_cpu_16_
# 314 | 0.8413 | 2636.80 | node_schedstat_running_seconds_total_cpu_22_
# 315 | 0.8410 | 2637.45 | node_schedstat_running_seconds_total_cpu_23_
# 316 | 0.8410 | 2637.46 | node_schedstat_waiting_seconds_total_cpu_0_
# 317 | 0.8409 | 2637.61 | node_schedstat_running_seconds_total_cpu_21_
# 318 | 0.8403 | 2638.76 | node_schedstat_running_seconds_total_cpu_1_
# 319 | 0.8398 | 2639.94 | node_nfsd_requests_total_method_Removeproto_4_
# 320 | 0.8398 | 2639.94 | node_nfs_requests_total_method_Removeproto_4_
# 321 | 0.8397 | 2640.16 | node_cpu_seconds_total_cpu_20mode_system_
# 322 | 0.8396 | 2640.28 | node_schedstat_running_seconds_total_cpu_0_
# 323 | 0.8385 | 2642.73 | node_softnet_processed_total_cpu_17_
# 324 | 0.8384 | 2642.85 | node_schedstat_running_seconds_total_cpu_7_
# 325 | 0.8383 | 2643.03 | node_cpu_seconds_total_cpu_6mode_system_
# 326 | 0.8383 | 2643.14 | node_cpu_seconds_total_cpu_2mode_system_
# 327 | 0.8381 | 2643.53 | node_cpu_seconds_total_cpu_16mode_system_
# 328 | 0.8371 | 2645.56 | node_cpu_seconds_total_cpu_13mode_system_
# 329 | 0.8370 | 2645.88 | node_cpu_seconds_total_cpu_18mode_system_
# 330 | 0.8369 | 2646.03 | node_cpu_seconds_total_cpu_14mode_system_
# 331 | 0.8368 | 2646.18 | node_cpu_seconds_total_cpu_3mode_system_
# 332 | 0.8368 | 2646.27 | node_cpu_seconds_total_cpu_17mode_system_
# 333 | 0.8365 | 2646.90 | node_cpu_seconds_total_cpu_11mode_system_
# 334 | 0.8363 | 2647.34 | node_cpu_seconds_total_cpu_4mode_system_
# 335 | 0.8362 | 2647.46 | node_cpu_seconds_total_cpu_15mode_system_
# 336 | 0.8359 | 2648.17 | node_cpu_seconds_total_cpu_19mode_system_
# 337 | 0.8357 | 2648.44 | node_cpu_seconds_total_cpu_8mode_system_
# 338 | 0.8357 | 2648.49 | node_schedstat_waiting_seconds_total_cpu_17_
# 339 | 0.8355 | 2649.04 | node_network_receive_packets_total_device_tun0_
# 340 | 0.8353 | 2649.41 | node_cpu_seconds_total_cpu_22mode_system_
# 341 | 0.8353 | 2649.42 | node_cpu_seconds_total_cpu_23mode_softirq_
# 342 | 0.8352 | 2649.55 | node_cpu_seconds_total_cpu_1mode_system_
# 343 | 0.8350 | 2650.02 | node_cpu_seconds_total_cpu_12mode_system_
# 344 | 0.8343 | 2651.43 | node_cpu_seconds_total_cpu_21mode_system_
# 345 | 0.8339 | 2652.28 | node_cpu_seconds_total_cpu_10mode_system_
# 346 | 0.8338 | 2652.55 | node_cpu_seconds_total_cpu_9mode_system_
# 347 | 0.8335 | 2653.13 | node_cpu_seconds_total_cpu_5mode_system_
# 348 | 0.8333 | 2653.50 | node_cpu_seconds_total_cpu_22mode_softirq_
# 349 | 0.8332 | 2653.59 | node_cpu_seconds_total_cpu_21mode_softirq_
# 350 | 0.8331 | 2653.87 | node_cpu_seconds_total_cpu_0mode_system_
# 351 | 0.8319 | 2656.40 | node_cpu_seconds_total_cpu_23mode_system_
# 352 | 0.8317 | 2656.81 | node_cpu_seconds_total_cpu_7mode_system_
# 353 | 0.8311 | 2657.93 | node_cpu_seconds_total_cpu_2mode_softirq_
# 354 | 0.8302 | 2659.70 | node_cpu_seconds_total_cpu_18mode_softirq_
# 355 | 0.8302 | 2659.86 | node_cpu_seconds_total_cpu_19mode_softirq_
# 356 | 0.8290 | 2662.18 | node_cpu_seconds_total_cpu_14mode_softirq_
# 357 | 0.8289 | 2662.28 | node_cpu_seconds_total_cpu_3mode_softirq_
# 358 | 0.8286 | 2663.02 | node_cpu_seconds_total_cpu_10mode_softirq_
# 359 | 0.8275 | 2665.17 | node_cpu_seconds_total_cpu_15mode_softirq_
# 360 | 0.8274 | 2665.30 | node_cpu_seconds_total_cpu_20mode_softirq_
# 361 | 0.8268 | 2666.44 | node_cpu_seconds_total_cpu_4mode_softirq_
# 362 | 0.8267 | 2666.81 | node_cpu_seconds_total_cpu_11mode_softirq_
# 363 | 0.8266 | 2666.99 | node_cpu_seconds_total_cpu_13mode_softirq_
# 364 | 0.8246 | 2670.82 | node_cpu_seconds_total_cpu_6mode_softirq_
# 365 | 0.8235 | 2672.89 | node_network_transmit_packets_total_device_cni0_
# 366 | 0.8228 | 2674.26 | node_cpu_seconds_total_cpu_12mode_softirq_
# 367 | 0.8227 | 2674.47 | node_cpu_seconds_total_cpu_9mode_softirq_
# 368 | 0.8226 | 2674.61 | node_cpu_seconds_total_cpu_5mode_softirq_
# 369 | 0.8223 | 2675.36 | node_cpu_seconds_total_cpu_16mode_softirq_
# 370 | 0.8221 | 2675.66 | node_network_receive_bytes_total_device_cni0_
# 371 | 0.8219 | 2676.11 | node_cpu_seconds_total_cpu_8mode_softirq_
# 372 | 0.8213 | 2677.19 | node_cpu_seconds_total_cpu_17mode_softirq_
# 373 | 0.8211 | 2677.52 | node_cpu_seconds_total_cpu_7mode_softirq_
# 374 | 0.8168 | 2685.59 | node_network_receive_packets_total_device_cni0_
# 375 | 0.8085 | 2700.73 | node_netstat_Tcp_PassiveOpens
# 376 | 0.8073 | 2703.00 | node_vmstat_pgfault
# 377 | 0.8067 | 2703.96 | node_netstat_Udp_InDatagrams
# 378 | 0.8067 | 2704.01 | node_forks_total
# 379 | 0.8064 | 2704.45 | node_load15
# 380 | 0.7978 | 2719.34 | node_netstat_TcpExt_TCPSynRetrans
# 381 | 0.7965 | 2721.45 | node_netstat_Tcp_RetransSegs
# 382 | 0.7949 | 2724.10 | node_disk_reads_completed_total_device_sda_
# 383 | 0.7524 | 2788.36 | go_memstats_buck_hash_sys_bytes
# 384 | 0.7524 | 2788.36 | go_memstats_other_sys_bytes
# 385 | 0.7461 | 2796.92 | node_pressure_memory_waiting_seconds_total
# 386 | 0.7420 | 2802.48 | node_pressure_memory_stalled_seconds_total
# 387 | 0.7407 | 2804.17 | node_vmstat_pgmajfault
# 388 | 0.7390 | 2806.35 | node_scrape_collector_duration_seconds_collector_netdev_
# 389 | 0.7331 | 2814.03 | go_memstats_heap_objects
# 390 | 0.7087 | 2843.81 | node_timex_frequency_adjustment_ratio
# 391 | 0.6837 | 2871.94 | node_netstat_Icmp_InErrors
# 392 | 0.6345 | 2921.22 | node_cpu_seconds_total_cpu_17mode_nice_
# 393 | 0.6276 | 2927.60 | node_cpu_seconds_total_cpu_6mode_nice_
# 394 | 0.6249 | 2930.04 | node_cpu_seconds_total_cpu_3mode_nice_
# 395 | 0.6217 | 2932.91 | node_cpu_seconds_total_cpu_18mode_nice_
# 396 | 0.6217 | 2932.91 | node_cpu_seconds_total_cpu_20mode_nice_
# 397 | 0.6049 | 2947.71 | node_cpu_seconds_total_cpu_7mode_nice_
# 398 | 0.5931 | 2957.77 | node_cpu_seconds_total_cpu_10mode_nice_
# 399 | 0.5899 | 2960.48 | node_cpu_seconds_total_cpu_9mode_nice_
# 400 | 0.5861 | 2963.62 | node_cpu_seconds_total_cpu_12mode_nice_
# 401 | 0.5835 | 2965.77 | cpu
# 402 | 0.5767 | 2971.29 | node_nfs_requests_total_method_Readproto_4_
# 403 | 0.5767 | 2971.29 | node_nfsd_requests_total_method_Readproto_4_
# 404 | 0.5694 | 2977.11 | node_cpu_seconds_total_cpu_14mode_nice_
# 405 | 0.5662 | 2979.64 | node_timex_estimated_error_seconds
# 406 | 0.5590 | 2985.23 | node_cpu_seconds_total_cpu_22mode_nice_
# 407 | 0.5538 | 2989.26 | node_cpu_seconds_total_cpu_13mode_nice_
# 408 | 0.5403 | 2999.42 | node_nfsd_disk_bytes_read_total
# 409 | 0.5373 | 3001.62 | node_cpu_seconds_total_cpu_15mode_nice_
# 410 | 0.5210 | 3013.43 | node_hwmon_temp_celsius_chip_platform_coretemp_0sensor_temp5_
# 411 | 0.4883 | 3035.92 | node_timex_loop_time_constant
# 412 | 0.4790 | 3042.07 | go_gc_duration_seconds_quantile_05_
# 413 | 0.4659 | 3050.51 | go_gc_duration_seconds_quantile_075_
# 414 | 0.4140 | 3082.16 | node_hwmon_temp_celsius_chip_platform_coretemp_0sensor_temp4_
# 415 | 0.4123 | 3083.16 | node_hwmon_temp_celsius_chip_platform_coretemp_0sensor_temp6_
# 416 | 0.4119 | 3083.36 | node_hwmon_temp_celsius_chip_platform_coretemp_0sensor_temp12_
# 417 | 0.4094 | 3084.84 | node_cpu_seconds_total_cpu_1mode_nice_
# 418 | 0.4050 | 3087.36 | node_cpu_seconds_total_cpu_8mode_nice_
# 419 | 0.3868 | 3097.62 | go_memstats_heap_alloc_bytes
# 420 | 0.3860 | 3098.11 | go_memstats_alloc_bytes
# 421 | 0.3756 | 3103.83 | node_memory_DirectMap2M_bytes
# 422 | 0.3756 | 3103.83 | node_memory_DirectMap4k_bytes
# 423 | 0.3729 | 3105.30 | node_hwmon_temp_celsius_chip_platform_coretemp_0sensor_temp13_
# 424 | 0.3690 | 3107.39 | node_procs_blocked
# 425 | 0.3551 | 3114.84 | node_thermal_zone_temp_type_x86_pkg_tempzone_0_
# 426 | 0.3532 | 3115.83 | node_hwmon_temp_celsius_chip_platform_coretemp_0sensor_temp1_
# 427 | 0.3512 | 3116.90 | node_hwmon_temp_celsius_chip_platform_coretemp_0sensor_temp15_
# 428 | 0.3394 | 3123.01 | node_hwmon_temp_celsius_chip_platform_coretemp_0sensor_temp3_
# 429 | 0.3357 | 3124.95 | node_entropy_available_bits
# 430 | 0.3291 | 3128.31 | node_hwmon_temp_celsius_chip_platform_coretemp_0sensor_temp14_
# 431 | 0.3238 | 3131.00 | node_netstat_Tcp_InErrs
# 432 | 0.3101 | 3137.83 | node_hwmon_temp_celsius_chip_platform_coretemp_0sensor_temp2_
# 433 | 0.2955 | 3144.96 | node_cpu_seconds_total_cpu_11mode_nice_
# 434 | 0.2856 | 3149.73 | go_memstats_next_gc_bytes
# 435 | 0.2721 | 3156.09 | node_hwmon_temp_celsius_chip_platform_coretemp_0sensor_temp10_
# 436 | 0.2402 | 3170.73 | node_cpu_seconds_total_cpu_16mode_nice_
# 437 | 0.2268 | 3176.72 | node_disk_io_now_device_dm_0_
# 438 | 0.2251 | 3177.46 | node_cpu_seconds_total_cpu_23mode_nice_
# 439 | 0.1943 | 3190.75 | node_hwmon_temp_celsius_chip_platform_coretemp_0sensor_temp11_
# 440 | 0.1784 | 3197.40 | node_cpu_scaling_frequency_hertz_cpu_12_
# 441 | 0.1728 | 3199.73 | node_sockstat_TCP_tw
# 442 | 0.1651 | 3202.87 | node_memory_Mapped_bytes
# 443 | 0.1567 | 3206.30 | node_hwmon_temp_celsius_chip_platform_coretemp_0sensor_temp7_
# 444 | 0.1560 | 3206.57 | node_sockstat_TCP_mem
# 445 | 0.1556 | 3206.75 | node_sockstat_TCP_mem_bytes
# 446 | 0.1537 | 3207.48 | node_cpu_scaling_frequency_hertz_cpu_7_
# 447 | 0.1492 | 3209.31 | node_cpu_scaling_frequency_hertz_cpu_0_
# 448 | 0.1478 | 3209.87 | node_cpu_scaling_frequency_hertz_cpu_19_
# 449 | 0.1451 | 3210.94 | node_cpu_scaling_frequency_hertz_cpu_5_
# 450 | 0.1440 | 3211.38 | node_cpu_seconds_total_cpu_0mode_nice_
# 451 | 0.1422 | 3212.09 | node_cpu_scaling_frequency_hertz_cpu_18_
# 452 | 0.1321 | 3216.10 | node_scrape_collector_duration_seconds_collector_udp_queues_
# 453 | 0.1270 | 3218.11 | node_cpu_scaling_frequency_hertz_cpu_2_
# 454 | 0.1256 | 3218.64 | node_cpu_scaling_frequency_hertz_cpu_9_
# 455 | 0.1250 | 3218.86 | node_cpu_scaling_frequency_hertz_cpu_22_
# 456 | 0.1219 | 3220.08 | node_cpu_scaling_frequency_hertz_cpu_1_
# 457 | 0.1200 | 3220.80 | node_cpu_scaling_frequency_hertz_cpu_3_
# 458 | 0.1196 | 3220.98 | node_cpu_scaling_frequency_hertz_cpu_8_
# 459 | 0.1185 | 3221.42 | node_timex_status
# 460 | 0.1172 | 3221.91 | node_cpu_scaling_frequency_hertz_cpu_15_
# 461 | 0.1113 | 3224.17 | node_cpu_scaling_frequency_hertz_cpu_20_
# 462 | 0.1066 | 3225.98 | node_cpu_scaling_frequency_hertz_cpu_10_
# 463 | 0.1036 | 3227.13 | node_cpu_scaling_frequency_hertz_cpu_23_
# 464 | 0.1033 | 3227.24 | node_cpu_scaling_frequency_hertz_cpu_14_
# 465 | 0.1026 | 3227.49 | node_cpu_scaling_frequency_hertz_cpu_11_
# 466 | 0.1001 | 3228.45 | node_memory_Writeback_bytes
# 467 | 0.0974 | 3229.45 | node_cpu_scaling_frequency_hertz_cpu_16_
# 468 | 0.0951 | 3230.33 | node_cpu_scaling_frequency_hertz_cpu_4_
# 469 | 0.0936 | 3230.91 | node_cpu_scaling_frequency_hertz_cpu_17_
# 470 | 0.0935 | 3230.94 | node_cpu_scaling_frequency_hertz_cpu_21_
# 471 | 0.0885 | 3232.83 | node_procs_running
# 472 | 0.0817 | 3235.36 | node_cpu_scaling_frequency_hertz_cpu_6_
# 473 | 0.0768 | 3237.17 | node_scrape_collector_duration_seconds_collector_arp_
# 474 | 0.0729 | 3238.58 | node_cpu_scaling_frequency_hertz_cpu_13_
# 475 | 0.0690 | 3240.03 | node_sockstat_TCP6_inuse
# 476 | 0.0643 | 3241.75 | go_gc_duration_seconds_quantile_1_
# 477 | 0.0361 | 3251.86 | node_rapl_package_joules_total_index_0_
# 478 | 0.0361 | 3251.86 | node_cpu_seconds_total_cpu_4mode_nice_
# 479 | 0.0347 | 3252.38 | go_memstats_heap_inuse_bytes
# 480 | 0.0268 | 3255.15 | promhttp_metric_handler_requests_in_flight
# 481 | 0.0252 | 3255.71 | go_gc_duration_seconds_quantile_025_
# 482 | 0.0251 | 3255.74 | node_memory_AnonHugePages_bytes
# 483 | 0.0240 | 3256.13 | go_memstats_heap_sys_bytes
# 484 | 0.0232 | 3256.41 | node_scrape_collector_duration_seconds_collector_stat_
# 485 | 0.0232 | 3256.42 | node_timex_offset_seconds
# 486 | 0.0186 | 3258.00 | go_memstats_gc_sys_bytes
# 487 | 0.0180 | 3258.23 | node_rapl_dram_joules_total_index_0_
# 488 | 0.0164 | 3258.76 | process_open_fds
# 489 | 0.0163 | 3258.80 | go_memstats_stack_sys_bytes
# 490 | 0.0163 | 3258.80 | go_memstats_stack_inuse_bytes
# 491 | 0.0160 | 3258.92 | node_scrape_collector_duration_seconds_collector_schedstat_
# 492 | 0.0156 | 3259.06 | node_scrape_collector_duration_seconds_collector_mdadm_
# 493 | 0.0115 | 3260.46 | go_memstats_mspan_inuse_bytes
# 494 | 0.0107 | 3260.74 | node_scrape_collector_duration_seconds_collector_thermal_zone_
# 495 | 0.0104 | 3260.84 | node_timex_maxerror_seconds
# 496 | 0.0092 | 3261.24 | go_memstats_heap_idle_bytes
# 497 | 0.0080 | 3261.66 | node_netstat_IpExt_OutOctets
# 498 | 0.0080 | 3259.67 | node_disk_written_bytes_total_device_dm_0_
# 499 | 0.0080 | 3261.68 | go_memstats_heap_released_bytes
# 500 | 0.0077 | 3259.77 | node_disk_written_bytes_total_device_sda_
