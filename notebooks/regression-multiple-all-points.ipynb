# %% [markdown]
# # Multiple regression on all data points (not on means)

# %%
from helpers import (
    add_instances_n,
    draw_regression_graph,
    fit_regression,
    get_experiments_data,
    get_attach_indexes,
    get_data_with_metrics,
)

# %% [markdown]
# ## Redis YCSB 6x10min

# %%
experiment_name = 'redis_ycsb_6x10'

exp_name, df = next(get_data_with_metrics(experiment_name, instances_n=6))

df.head()
# Out:
#   cbtool_time    cpu_time  app_latency  app_throughput     cpu        memory  \
# 0  1590502163  1590502164     0.078133     9606.147935  1686.0  4.167684e+09
# 1  1590502224  1590502225     0.080170     9532.888465  1677.0  4.168221e+09
# 2  1590502285  1590502285     0.074826    10362.694301  1659.0  4.167287e+09
# 3  1590502346  1590502346     0.074463    10438.413361  1747.0  4.181807e+09
# 4  1590502407  1590502406     0.078476     9910.802775  1763.0  4.262556e+09
#
#    instances_n
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ### `app_latency` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.910
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     624.8
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           4.43e-34
# Time:                        19:46:21   Log-Likelihood:                 275.92
# No. Observations:                  64   AIC:                            -547.8
# Df Residuals:                      62   BIC:                            -543.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0698      0.001     74.920      0.000       0.068       0.072
# instances_n     0.0060      0.000     24.996      0.000       0.006       0.007
# ==============================================================================
# Omnibus:                        2.860   Durbin-Watson:                   1.179
# Prob(Omnibus):                  0.239   Jarque-Bera (JB):                1.614
# Skew:                          -0.016   Prob(JB):                        0.446
# Kurtosis:                       2.223   Cond. No.                         9.18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_latency` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     632.6
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           3.12e-34
# Time:                        19:46:21   Log-Likelihood:                 276.28
# No. Observations:                  64   AIC:                            -548.6
# Df Residuals:                      62   BIC:                            -544.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0657      0.001     61.002      0.000       0.064       0.068
# cpu         5.196e-06   2.07e-07     25.151      0.000    4.78e-06    5.61e-06
# ==============================================================================
# Omnibus:                        7.353   Durbin-Watson:                   1.314
# Prob(Omnibus):                  0.025   Jarque-Bera (JB):                6.577
# Skew:                          -0.731   Prob(JB):                       0.0373
# Kurtosis:                       3.576   Cond. No.                     1.37e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.913
# Method:                 Least Squares   F-statistic:                     330.9
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.79e-33
# Time:                        19:46:21   Log-Likelihood:                 278.07
# No. Observations:                  64   AIC:                            -550.1
# Df Residuals:                      61   BIC:                            -543.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0675      0.001     46.846      0.000       0.065       0.070
# instances_n     0.0029      0.002      1.875      0.066      -0.000       0.006
# cpu          2.736e-06   1.33e-06      2.061      0.044    8.14e-08    5.39e-06
# ==============================================================================
# Omnibus:                        2.136   Durbin-Watson:                   1.256
# Prob(Omnibus):                  0.344   Jarque-Bera (JB):                2.083
# Skew:                          -0.380   Prob(JB):                        0.353
# Kurtosis:                       2.550   Cond. No.                     2.51e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.51e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm

fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                     2602.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           2.41e-52
# Time:                        19:46:23   Log-Likelihood:                -456.45
# No. Observations:                  64   AIC:                             916.9
# Df Residuals:                      62   BIC:                             921.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     842.6536     86.892      9.698      0.000     668.959    1016.349
# instances_n  1150.9827     22.565     51.007      0.000    1105.876    1196.090
# ==============================================================================
# Omnibus:                       27.573   Durbin-Watson:                   1.187
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.316
# Skew:                           1.457   Prob(JB):                     4.36e-12
# Kurtosis:                       6.336   Cond. No.                         9.18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Redis YCSB 12x10min

# %%
experiment_name = 'redis_ycsb_12x10'

exp_name, df = next(get_data_with_metrics(experiment_name, instances_n=12))

df.head()
# Out:
#   cbtool_time    cpu_time  app_latency  app_throughput     cpu        memory  \
# 0  1590635972  1590635970     0.073216    10570.824524  1650.0  6.057599e+09
# 1  1590636022  1590636020     0.076797    10183.299389  1670.0  5.943132e+09
# 2  1590636083  1590636081     0.075290    10266.940452  1638.0  6.086791e+09
# 3  1590636144  1590636141     0.074385    10416.666667  1653.0  6.058856e+09
# 4  1590636205  1590636202     0.075853    10309.278351  1660.0  6.007448e+09
#
#    instances_n
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ### `app_latency` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.942
# Method:                 Least Squares   F-statistic:                     1964.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           8.08e-76
# Time:                        19:46:24   Log-Likelihood:                 469.10
# No. Observations:                 121   AIC:                            -934.2
# Df Residuals:                     119   BIC:                            -928.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0699      0.001     71.810      0.000       0.068       0.072
# instances_n     0.0061      0.000     44.318      0.000       0.006       0.006
# ==============================================================================
# Omnibus:                       14.304   Durbin-Watson:                   0.842
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               20.201
# Skew:                           0.610   Prob(JB):                     4.11e-05
# Kurtosis:                       4.587   Cond. No.                         15.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_latency` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.885
# Model:                            OLS   Adj. R-squared:                  0.884
# Method:                 Least Squares   F-statistic:                     913.8
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.12e-57
# Time:                        19:46:24   Log-Likelihood:                 426.65
# No. Observations:                 121   AIC:                            -849.3
# Df Residuals:                     119   BIC:                            -843.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0568      0.002     31.348      0.000       0.053       0.060
# cpu         7.391e-06   2.45e-07     30.229      0.000    6.91e-06    7.88e-06
# ==============================================================================
# Omnibus:                       34.054   Durbin-Watson:                   0.362
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               58.917
# Skew:                           1.269   Prob(JB):                     1.61e-13
# Kurtosis:                       5.291   Cond. No.                     2.06e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.06e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.942
# Method:                 Least Squares   F-statistic:                     973.8
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           4.50e-74
# Time:                        19:46:24   Log-Likelihood:                 469.10
# No. Observations:                 121   AIC:                            -932.2
# Df Residuals:                     118   BIC:                            -923.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0699      0.002     39.941      0.000       0.066       0.073
# instances_n     0.0061      0.001     10.955      0.000       0.005       0.007
# cpu          2.269e-08   6.95e-07      0.033      0.974   -1.35e-06     1.4e-06
# ==============================================================================
# Omnibus:                       14.316   Durbin-Watson:                   0.841
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               20.216
# Skew:                           0.611   Prob(JB):                     4.07e-05
# Kurtosis:                       4.587   Cond. No.                     2.88e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.88e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                     1801.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.03e-73
# Time:                        19:46:25   Log-Likelihood:                -958.06
# No. Observations:                 121   AIC:                             1920.
# Df Residuals:                     119   BIC:                             1926.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    2088.5088    129.048     16.184      0.000    1832.981    2344.036
# instances_n   777.9633     18.331     42.441      0.000     741.667     814.260
# ==============================================================================
# Omnibus:                       11.803   Durbin-Watson:                   0.121
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):                7.009
# Skew:                          -0.425   Prob(JB):                       0.0301
# Kurtosis:                       2.184   Cond. No.                         15.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Redis YCSB 12x20min

# %%
experiment_name = 'redis_ycsb_12x20'

exp_name, df = next(get_data_with_metrics(experiment_name, instances_n=12))

print(len(df))
df.head()
# Out:
# 235
#   cbtool_time    cpu_time  app_latency  app_throughput     cpu        memory  \
# 0  1591872872  1591872871     0.079693     9487.666034  1572.0  4.553658e+09
# 1  1591872933  1591872932     0.078356    10040.160643  1627.0  4.483006e+09
# 2  1591872994  1591872992     0.077941     9950.248756  1655.0  4.633547e+09
# 3  1591873055  1591873053     0.076327    10080.645161  1704.0  4.555633e+09
# 4  1591873111  1591873113     0.082048     9199.632015  1638.0  4.475527e+09
#
#    instances_n
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ### `app_latency` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     2932.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):          5.47e-134
# Time:                        19:46:27   Log-Likelihood:                 874.17
# No. Observations:                 235   AIC:                            -1744.
# Df Residuals:                     233   BIC:                            -1737.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0696      0.001     85.747      0.000       0.068       0.071
# instances_n     0.0062      0.000     54.148      0.000       0.006       0.006
# ==============================================================================
# Omnibus:                       26.000   Durbin-Watson:                   1.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.813
# Skew:                           0.665   Prob(JB):                     2.26e-09
# Kurtosis:                       4.516   Cond. No.                         15.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_latency` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.836
# Model:                            OLS   Adj. R-squared:                  0.835
# Method:                 Least Squares   F-statistic:                     1187.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           2.10e-93
# Time:                        19:46:27   Log-Likelihood:                 779.97
# No. Observations:                 235   AIC:                            -1556.
# Df Residuals:                     233   BIC:                            -1549.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0582      0.002     37.186      0.000       0.055       0.061
# cpu         7.292e-06   2.12e-07     34.449      0.000    6.88e-06    7.71e-06
# ==============================================================================
# Omnibus:                       28.312   Durbin-Watson:                   0.596
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.862
# Skew:                           0.865   Prob(JB):                     2.69e-08
# Kurtosis:                       3.753   Cond. No.                     2.02e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.02e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     1524.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):          3.63e-134
# Time:                        19:46:27   Log-Likelihood:                 878.86
# No. Observations:                 235   AIC:                            -1752.
# Df Residuals:                     232   BIC:                            -1741.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0729      0.001     54.861      0.000       0.070       0.075
# instances_n     0.0075      0.000     17.500      0.000       0.007       0.008
# cpu         -1.623e-06   5.28e-07     -3.073      0.002   -2.66e-06   -5.83e-07
# ==============================================================================
# Omnibus:                       22.102   Durbin-Watson:                   1.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.850
# Skew:                           0.543   Prob(JB):                     9.96e-09
# Kurtosis:                       4.607   Cond. No.                     2.66e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.66e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     3117.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):          7.17e-137
# Time:                        19:46:28   Log-Likelihood:                -1877.8
# No. Observations:                 235   AIC:                             3760.
# Df Residuals:                     233   BIC:                             3767.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    2011.1317     98.907     20.333      0.000    1816.264    2205.999
# instances_n   785.1436     14.062     55.834      0.000     757.439     812.849
# ==============================================================================
# Omnibus:                       76.053   Durbin-Watson:                   0.517
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              269.950
# Skew:                          -1.314   Prob(JB):                     2.41e-59
# Kurtosis:                       7.545   Cond. No.                         15.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Linpack 6x10min

# %%
experiment_name = 'linpack_6x10'

exp_name, df = next(get_data_with_metrics(experiment_name, instances_n=6))

df.head()
# Out:
#   cbtool_time    cpu_time  app_latency  app_throughput     cpu        memory  \
# 0  1590625097  1590625102          NaN         33.2244  2030.0  5.366915e+09
# 1  1590625167  1590625163          NaN         33.2747  2047.0  5.345997e+09
# 2  1590625227  1590625223          NaN         33.3156  2017.0  5.345898e+09
# 3  1590625287  1590625284          NaN         33.4095  2063.0  5.328142e+09
# 4  1590625347  1590625344          NaN         33.3053  2016.0  5.329502e+09
#
#    instances_n
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ### `app_throughput` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_throughput', variable='instances_n')
# Out:
# /home/godul/.local/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in reduce
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     311.6
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           2.25e-22
# Time:                        19:46:29   Log-Likelihood:                -104.89
# No. Observations:                  49   AIC:                             213.8
# Df Residuals:                      47   BIC:                             217.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      36.6631      0.648     56.540      0.000      35.359      37.968
# instances_n    -3.2285      0.183    -17.653      0.000      -3.596      -2.861
# ==============================================================================
# Omnibus:                        1.482   Durbin-Watson:                   1.677
# Prob(Omnibus):                  0.477   Jarque-Bera (JB):                0.730
# Skew:                           0.229   Prob(JB):                        0.694
# Kurtosis:                       3.384   Cond. No.                         8.15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_throughput` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ cpu')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_throughput', variable='cpu')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                     318.5
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.44e-22
# Time:                        19:46:29   Log-Likelihood:                -104.42
# No. Observations:                  49   AIC:                             212.8
# Df Residuals:                      47   BIC:                             216.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     37.8626      0.702     53.950      0.000      36.451      39.274
# cpu           -0.0021      0.000    -17.848      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                        0.068   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.967   Jarque-Bera (JB):                0.040
# Skew:                           0.040   Prob(JB):                        0.980
# Kurtosis:                       2.885   Cond. No.                     1.43e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /home/godul/.local/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in reduce
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### `app_throughput` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n + cpu')
print(results.summary())
# Out:
# /home/godul/.local/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in reduce
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.876
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     161.8
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.53e-21
# Time:                        19:46:29   Log-Likelihood:                -103.62
# No. Observations:                  49   AIC:                             213.2
# Df Residuals:                      46   BIC:                             218.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      37.3975      0.793     47.156      0.000      35.801      38.994
# instances_n    -1.4352      1.162     -1.235      0.223      -3.774       0.904
# cpu            -0.0012      0.001     -1.562      0.125      -0.003       0.000
# ==============================================================================
# Omnibus:                        0.769   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.681   Jarque-Bera (JB):                0.366
# Skew:                           0.205   Prob(JB):                        0.833
# Kurtosis:                       3.103   Cond. No.                     2.56e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.56e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
# /home/godul/.local/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in reduce
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.975
# Method:                 Least Squares   F-statistic:                     1909.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.04e-39
# Time:                        19:46:30   Log-Likelihood:                -362.91
# No. Observations:                  49   AIC:                             729.8
# Df Residuals:                      47   BIC:                             733.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     633.3810    125.536      5.045      0.000     380.834     885.928
# instances_n  1546.7684     35.406     43.687      0.000    1475.541    1617.996
# ==============================================================================
# Omnibus:                        3.408   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.182   Jarque-Bera (JB):                2.461
# Skew:                           0.333   Prob(JB):                        0.292
# Kurtosis:                       3.872   Cond. No.                         8.15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Linpack 12x10min

# %%
experiment_name = 'linpack_12x10'

exp_name, df = next(get_data_with_metrics(experiment_name, instances_n=12))

df.head()
# Out:
#   cbtool_time    cpu_time  app_latency  app_throughput     cpu        memory  \
# 0  1590687141  1590687146          NaN         33.4191  2071.0  6.660665e+09
# 1  1590687211  1590687207          NaN         33.1738  2035.0  6.646727e+09
# 2  1590687271  1590687267          NaN         33.3837  2056.0  6.647034e+09
# 3  1590687331  1590687328          NaN         33.2996  2024.0  6.646743e+09
# 4  1590687391  1590687388          NaN         33.4040  2055.0  6.643663e+09
#
#    instances_n
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ### `app_throughput` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n')
draw_regression_graph(results, df, metric_name='app_throughput', variable='instances_n')
print(results.summary())
# Out:
# /home/godul/.local/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in reduce
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     1029.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.53e-45
# Time:                        19:46:31   Log-Likelihood:                -168.69
# No. Observations:                  77   AIC:                             341.4
# Df Residuals:                      75   BIC:                             346.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      34.7215      0.470     73.917      0.000      33.786      35.657
# instances_n    -2.3730      0.074    -32.074      0.000      -2.520      -2.226
# ==============================================================================
# Omnibus:                        2.838   Durbin-Watson:                   1.136
# Prob(Omnibus):                  0.242   Jarque-Bera (JB):                2.181
# Skew:                          -0.261   Prob(JB):                        0.336
# Kurtosis:                       2.361   Cond. No.                         12.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_throughput` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ cpu')
draw_regression_graph(results, df, metric_name='app_throughput', variable='cpu')
print(results.summary())
# Out:
# /home/godul/.local/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in reduce
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.942
# Method:                 Least Squares   F-statistic:                     1245.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.88e-48
# Time:                        19:46:31   Log-Likelihood:                -161.81
# No. Observations:                  77   AIC:                             327.6
# Df Residuals:                      75   BIC:                             332.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.3423      0.543     72.447      0.000      38.260      40.424
# cpu           -0.0023   6.44e-05    -35.278      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                        5.485   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.064   Jarque-Bera (JB):                5.423
# Skew:                           0.383   Prob(JB):                       0.0665
# Kurtosis:                       4.050   Cond. No.                     2.00e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  2e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_throughput` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     891.5
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.64e-52
# Time:                        19:46:32   Log-Likelihood:                -148.14
# No. Observations:                  77   AIC:                             302.3
# Df Residuals:                      74   BIC:                             309.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      37.6721      0.546     69.010      0.000      36.584      38.760
# instances_n    -1.0657      0.190     -5.616      0.000      -1.444      -0.688
# cpu            -0.0013      0.000     -7.224      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                        6.113   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                5.498
# Skew:                           0.516   Prob(JB):                       0.0640
# Kurtosis:                       3.807   Cond. No.                     2.43e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /home/godul/.local/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in reduce
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
# /home/godul/.local/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in reduce
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.910
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     755.0
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           6.80e-41
# Time:                        19:46:33   Log-Likelihood:                -646.07
# No. Observations:                  77   AIC:                             1296.
# Df Residuals:                      75   BIC:                             1301.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    2260.3305    231.408      9.768      0.000    1799.342    2721.319
# instances_n  1001.4627     36.447     27.477      0.000     928.856    1074.069
# ==============================================================================
# Omnibus:                        0.526   Durbin-Watson:                   0.382
# Prob(Omnibus):                  0.769   Jarque-Bera (JB):                0.651
# Skew:                          -0.049   Prob(JB):                        0.722
# Kurtosis:                       2.560   Cond. No.                         12.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Linpack 12x20min

# %%
experiment_name = 'linpack_12x20'

exp_name, df = next(get_data_with_metrics(experiment_name, instances_n=12))

df.head()
# Out:
#   cbtool_time    cpu_time  app_latency  app_throughput     cpu        memory  \
# 0  1592311591  1592311594          NaN         33.3820  2035.0  4.546589e+09
# 1  1592311651  1592311654          NaN         33.3700  2034.0  4.547256e+09
# 2  1592311711  1592311715          NaN         33.3523  2034.0  4.545925e+09
# 3  1592311771  1592311775          NaN         32.2720  2057.0  4.546154e+09
# 4  1592311831  1592311836          NaN         33.1085  2044.0  4.545212e+09
#
#    instances_n
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ### `app_throughput` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n')
draw_regression_graph(results, df, metric_name='app_throughput', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.923
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     1796.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           5.21e-85
# Time:                        19:46:34   Log-Likelihood:                -326.28
# No. Observations:                 151   AIC:                             656.6
# Df Residuals:                     149   BIC:                             662.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      34.6673      0.328    105.597      0.000      34.019      35.316
# instances_n    -2.3729      0.056    -42.374      0.000      -2.484      -2.262
# ==============================================================================
# Omnibus:                        2.871   Durbin-Watson:                   1.290
# Prob(Omnibus):                  0.238   Jarque-Bera (JB):                2.908
# Skew:                          -0.325   Prob(JB):                        0.234
# Kurtosis:                       2.798   Cond. No.                         11.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /home/godul/.local/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in reduce
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### `app_throughput` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ cpu')
draw_regression_graph(results, df, metric_name='app_throughput', variable='cpu')
print(results.summary())
# Out:
# /home/godul/.local/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in reduce
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.924
# Method:                 Least Squares   F-statistic:                     1822.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.90e-85
# Time:                        19:46:34   Log-Likelihood:                -325.26
# No. Observations:                 151   AIC:                             654.5
# Df Residuals:                     149   BIC:                             660.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     38.5273      0.406     94.955      0.000      37.726      39.329
# cpu           -0.0021   4.98e-05    -42.685      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                        1.684   Durbin-Watson:                   1.562
# Prob(Omnibus):                  0.431   Jarque-Bera (JB):                1.606
# Skew:                          -0.250   Prob(JB):                        0.448
# Kurtosis:                       2.933   Cond. No.                     1.93e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.93e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_throughput` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     1293.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.84e-94
# Time:                        19:46:35   Log-Likelihood:                -300.02
# No. Observations:                 151   AIC:                             606.0
# Df Residuals:                     148   BIC:                             615.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      36.9478      0.401     92.050      0.000      36.155      37.741
# instances_n    -1.2008      0.157     -7.665      0.000      -1.510      -0.891
# cpu            -0.0011      0.000     -7.846      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                        3.221   Durbin-Watson:                   1.902
# Prob(Omnibus):                  0.200   Jarque-Bera (JB):                2.843
# Skew:                          -0.329   Prob(JB):                        0.241
# Kurtosis:                       3.137   Cond. No.                     2.30e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.3e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /home/godul/.local/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in reduce
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.909
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     1491.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.68e-79
# Time:                        19:46:36   Log-Likelihood:                -1262.3
# No. Observations:                 151   AIC:                             2529.
# Df Residuals:                     149   BIC:                             2535.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    2070.8036    161.576     12.816      0.000    1751.527    2390.080
# instances_n  1064.2900     27.560     38.617      0.000    1009.831    1118.749
# ==============================================================================
# Omnibus:                        2.003   Durbin-Watson:                   0.276
# Prob(Omnibus):                  0.367   Jarque-Bera (JB):                1.615
# Skew:                          -0.239   Prob(JB):                        0.446
# Kurtosis:                       3.168   Cond. No.                         11.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /home/godul/.local/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in reduce
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ## Wrk 6x10min

# %%
experiment_name = 'wrk_6x10'

exp_name, df = next(get_data_with_metrics(experiment_name, instances_n=6))

df.head()
# Out:
#   cbtool_time    cpu_time  app_latency  app_throughput     cpu        memory  \
# 0  1590630684  1590630688        10.63         18430.0  5637.0  5.403017e+09
# 1  1590630748  1590630748        10.66         18390.0  6295.0  5.402935e+09
# 2  1590630812  1590630809        23.02          5420.0  7917.0  5.401166e+09
# 3  1590631037  1590631042        34.40          6280.0  9357.0  6.026682e+09
# 4  1590631101  1590631103        29.26          3350.0  9394.0  6.015091e+09
#
#    instances_n
# 0          1.0
# 1          1.0
# 2          1.0
# 3          2.0
# 4          2.0

# %% [markdown]
# ### `app_latency` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.940
# Method:                 Least Squares   F-statistic:                     345.0
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.64e-14
# Time:                        19:46:36   Log-Likelihood:                -69.017
# No. Observations:                  23   AIC:                             142.0
# Df Residuals:                      21   BIC:                             144.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       3.9881      2.549      1.565      0.133      -1.313       9.289
# instances_n    12.6929      0.683     18.574      0.000      11.272      14.114
# ==============================================================================
# Omnibus:                        4.276   Durbin-Watson:                   1.908
# Prob(Omnibus):                  0.118   Jarque-Bera (JB):                1.799
# Skew:                          -0.319   Prob(JB):                        0.407
# Kurtosis:                       1.787   Cond. No.                         9.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_latency` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.799
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     83.70
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           8.99e-09
# Time:                        19:46:37   Log-Likelihood:                -83.409
# No. Observations:                  23   AIC:                             170.8
# Df Residuals:                      21   BIC:                             173.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -68.5138     12.785     -5.359      0.000     -95.101     -41.926
# cpu            0.0114      0.001      9.149      0.000       0.009       0.014
# ==============================================================================
# Omnibus:                        1.178   Durbin-Watson:                   0.497
# Prob(Omnibus):                  0.555   Jarque-Bera (JB):                0.904
# Skew:                          -0.186   Prob(JB):                        0.636
# Kurtosis:                       2.103   Cond. No.                     6.60e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.6e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.947
# Method:                 Least Squares   F-statistic:                     198.2
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           6.54e-14
# Time:                        19:46:37   Log-Likelihood:                -66.974
# No. Observations:                  23   AIC:                             139.9
# Df Residuals:                      20   BIC:                             143.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     -13.9079      9.384     -1.482      0.154     -33.482       5.667
# instances_n    10.4395      1.310      7.969      0.000       7.707      13.172
# cpu             0.0025      0.001      1.972      0.063      -0.000       0.005
# ==============================================================================
# Omnibus:                        2.668   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.263   Jarque-Bera (JB):                1.913
# Skew:                          -0.703   Prob(JB):                        0.384
# Kurtosis:                       2.868   Cond. No.                     9.71e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.71e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.761
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     66.79
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           5.84e-08
# Time:                        19:46:38   Log-Likelihood:                -185.72
# No. Observations:                  23   AIC:                             375.4
# Df Residuals:                      21   BIC:                             377.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    7087.6865    407.339     17.400      0.000    6240.579    7934.794
# instances_n   892.4514    109.206      8.172      0.000     665.346    1119.557
# ==============================================================================
# Omnibus:                       14.002   Durbin-Watson:                   0.390
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               12.836
# Skew:                          -1.563   Prob(JB):                      0.00163
# Kurtosis:                       4.903   Cond. No.                         9.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Wrk 12x10min

# %%
experiment_name = 'wrk_12x10'

exp_name, df = next(get_data_with_metrics(experiment_name, instances_n=12))

df.head()
# Out:
#   cbtool_time    cpu_time  app_latency  app_throughput     cpu        memory  \
# 0  1591793254  1591793257        21.17          5300.0  6690.0  6.803329e+09
# 1  1591793607  1591793610        33.10          3090.0  9134.0  6.910165e+09
# 2  1591793672  1591793671        32.78          3020.0  9469.0  6.913380e+09
# 3  1591793737  1591793732        31.08          4100.0  9717.0  6.897734e+09
# 4  1591794095  1591794096        31.03          4130.0  9225.0  6.900322e+09
#
#    instances_n
# 0          1.0
# 1          2.0
# 2          2.0
# 3          2.0
# 4          2.0

# %% [markdown]
# ### `app_latency` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                     1635.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           4.62e-34
# Time:                        19:46:39   Log-Likelihood:                -125.99
# No. Observations:                  42   AIC:                             256.0
# Df Residuals:                      40   BIC:                             259.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      17.5402      1.708     10.270      0.000      14.088      20.992
# instances_n     9.5940      0.237     40.433      0.000       9.114      10.074
# ==============================================================================
# Omnibus:                        4.589   Durbin-Watson:                   1.513
# Prob(Omnibus):                  0.101   Jarque-Bera (JB):                3.557
# Skew:                           0.696   Prob(JB):                        0.169
# Kurtosis:                       3.311   Cond. No.                         16.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_latency` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.689
# Model:                            OLS   Adj. R-squared:                  0.682
# Method:                 Least Squares   F-statistic:                     88.82
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.04e-11
# Time:                        19:46:39   Log-Likelihood:                -179.86
# No. Observations:                  42   AIC:                             363.7
# Df Residuals:                      40   BIC:                             367.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -192.5900     28.973     -6.647      0.000    -251.146    -134.034
# cpu            0.0243      0.003      9.425      0.000       0.019       0.030
# ==============================================================================
# Omnibus:                        4.839   Durbin-Watson:                   0.334
# Prob(Omnibus):                  0.089   Jarque-Bera (JB):                4.296
# Skew:                           0.783   Prob(JB):                        0.117
# Kurtosis:                       2.963   Cond. No.                     1.17e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.17e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                     1197.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           9.86e-36
# Time:                        19:46:39   Log-Likelihood:                -117.61
# No. Observations:                  42   AIC:                             241.2
# Df Residuals:                      39   BIC:                             246.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     -22.2759      9.215     -2.417      0.020     -40.914      -3.637
# instances_n     8.5038      0.318     26.770      0.000       7.861       9.146
# cpu             0.0042      0.001      4.373      0.000       0.002       0.006
# ==============================================================================
# Omnibus:                       10.947   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               10.416
# Skew:                           1.093   Prob(JB):                      0.00547
# Kurtosis:                       4.082   Cond. No.                     1.62e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.62e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.606
# Method:                 Least Squares   F-statistic:                     64.17
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           7.65e-10
# Time:                        19:46:41   Log-Likelihood:                -332.55
# No. Observations:                  42   AIC:                             669.1
# Df Residuals:                      40   BIC:                             672.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    9491.7034    233.538     40.643      0.000    9019.705    9963.702
# instances_n   259.9017     32.445      8.010      0.000     194.327     325.476
# ==============================================================================
# Omnibus:                       40.344   Durbin-Watson:                   0.392
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              154.984
# Skew:                          -2.289   Prob(JB):                     2.22e-34
# Kurtosis:                      11.222   Cond. No.                         16.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Wrk 12x20min

# %%
experiment_name = 'wrk_12x20'

exp_name, df = next(get_data_with_metrics(experiment_name, instances_n=12))

df.head()
# Out:
#   cbtool_time    cpu_time  app_latency  app_throughput     cpu        memory  \
# 0  1591802843  1591802848        15.24          8880.0  7167.0  4.690260e+09
# 1  1591802907  1591802908        10.08         20180.0  5906.0  4.676293e+09
# 2  1591802971  1591802969        20.20          5360.0  7869.0  4.687049e+09
# 3  1591803449  1591803453        21.11          5340.0  6597.0  4.683792e+09
# 4  1591803513  1591803514        10.05         20140.0  6163.0  4.669866e+09
#
#    instances_n
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ### `app_latency` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     2273.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.65e-60
# Time:                        19:46:41   Log-Likelihood:                -264.11
# No. Observations:                  82   AIC:                             532.2
# Df Residuals:                      80   BIC:                             537.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      14.0505      1.468      9.574      0.000      11.130      16.971
# instances_n    10.1371      0.213     47.673      0.000       9.714      10.560
# ==============================================================================
# Omnibus:                        5.551   Durbin-Watson:                   1.279
# Prob(Omnibus):                  0.062   Jarque-Bera (JB):                5.251
# Skew:                          -0.619   Prob(JB):                       0.0724
# Kurtosis:                       3.059   Cond. No.                         15.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_latency` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.716
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     201.8
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.39e-23
# Time:                        19:46:41   Log-Likelihood:                -351.11
# No. Observations:                  82   AIC:                             706.2
# Df Residuals:                      80   BIC:                             711.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -148.2236     15.911     -9.316      0.000    -179.888    -116.559
# cpu            0.0205      0.001     14.207      0.000       0.018       0.023
# ==============================================================================
# Omnibus:                        5.369   Durbin-Watson:                   0.492
# Prob(Omnibus):                  0.068   Jarque-Bera (JB):                5.421
# Skew:                           0.620   Prob(JB):                       0.0665
# Kurtosis:                       2.780   Cond. No.                     8.96e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.96e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.978
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     1787.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.71e-66
# Time:                        19:46:42   Log-Likelihood:                -245.55
# No. Observations:                  82   AIC:                             497.1
# Df Residuals:                      79   BIC:                             504.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     -25.1343      5.946     -4.227      0.000     -36.969     -13.300
# instances_n     8.6491      0.279     30.949      0.000       8.093       9.205
# cpu             0.0044      0.001      6.724      0.000       0.003       0.006
# ==============================================================================
# Omnibus:                        5.587   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.061   Jarque-Bera (JB):                8.407
# Skew:                          -0.053   Prob(JB):                       0.0149
# Kurtosis:                       4.565   Cond. No.                     1.21e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.627
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                     134.5
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           8.14e-19
# Time:                        19:46:43   Log-Likelihood:                -667.34
# No. Observations:                  82   AIC:                             1339.
# Df Residuals:                      80   BIC:                             1343.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    8875.9065    200.554     44.257      0.000    8476.791    9275.022
# instances_n   337.0491     29.058     11.599      0.000     279.221     394.877
# ==============================================================================
# Omnibus:                       44.204   Durbin-Watson:                   0.429
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              116.619
# Skew:                          -1.881   Prob(JB):                     4.75e-26
# Kurtosis:                       7.471   Cond. No.                         15.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Hadoop 6x20min

# %%
experiment_name = 'hadoop_6x20'

exp_name, df = next(get_data_with_metrics(experiment_name, instances_n=6))
df['app_throughput'] = df['app_throughput'].astype(float)

df.head()
# Out:
#   cbtool_time    cpu_time  app_latency  app_throughput     cpu        memory  \
# 0  1591913731  1591913729      24710.0         40469.0  1464.0  7.047311e+09
# 1  1591914209  1591914213      25673.0         38951.0  1345.0  7.115739e+09
# 2  1591914276  1591914274      24732.0         40433.0  1449.0  7.137055e+09
# 3  1591914683  1591914687      25273.0         39567.0  1370.0  7.217549e+09
# 4  1591914749  1591914748      23754.0         42098.0  1499.0  7.238173e+09
#
#    instances_n
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ### `app_throughput` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_throughput', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.837
# Method:                 Least Squares   F-statistic:                     77.77
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           4.33e-07
# Time:                        20:01:21   Log-Likelihood:                -140.02
# No. Observations:                  16   AIC:                             284.0
# Df Residuals:                      14   BIC:                             285.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    4.218e+04    793.249     53.174      0.000    4.05e+04    4.39e+04
# instances_n -2085.6728    236.501     -8.819      0.000   -2592.917   -1578.428
# ==============================================================================
# Omnibus:                        4.085   Durbin-Watson:                   2.101
# Prob(Omnibus):                  0.130   Jarque-Bera (JB):                2.204
# Skew:                          -0.896   Prob(JB):                        0.332
# Kurtosis:                       3.313   Cond. No.                         6.95
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /home/godul/.local/lib/python3.7/site-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))

# %% [markdown]
# ### `app_throughput` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ cpu')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_throughput', variable='cpu')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.838
# Model:                            OLS   Adj. R-squared:                  0.826
# Method:                 Least Squares   F-statistic:                     72.29
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           6.69e-07
# Time:                        20:01:26   Log-Likelihood:                -140.51
# No. Observations:                  16   AIC:                             285.0
# Df Residuals:                      14   BIC:                             286.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.241e+04    845.010     50.190      0.000    4.06e+04    4.42e+04
# cpu           -1.4719      0.173     -8.503      0.000      -1.843      -1.101
# ==============================================================================
# Omnibus:                        0.510   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.775   Jarque-Bera (JB):                0.379
# Skew:                          -0.331   Prob(JB):                        0.827
# Kurtosis:                       2.637   Cond. No.                     9.79e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.79e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /home/godul/.local/lib/python3.7/site-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))

# %% [markdown]
# ### `app_throughput` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.827
# Method:                 Least Squares   F-statistic:                     36.80
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           4.43e-06
# Time:                        20:01:33   Log-Likelihood:                -139.89
# No. Observations:                  16   AIC:                             285.8
# Df Residuals:                      13   BIC:                             288.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    4.229e+04    851.563     49.663      0.000    4.05e+04    4.41e+04
# instances_n -1445.6615   1409.848     -1.025      0.324   -4491.454    1600.131
# cpu            -0.4612      1.001     -0.461      0.652      -2.623       1.701
# ==============================================================================
# Omnibus:                        3.274   Durbin-Watson:                   2.137
# Prob(Omnibus):                  0.195   Jarque-Bera (JB):                1.733
# Skew:                          -0.801   Prob(JB):                        0.420
# Kurtosis:                       3.181   Cond. No.                     1.65e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.65e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /home/godul/.local/lib/python3.7/site-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     455.5
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           4.45e-12
# Time:                        20:01:51   Log-Likelihood:                -119.36
# No. Observations:                  16   AIC:                             242.7
# Df Residuals:                      14   BIC:                             244.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     241.5079    218.082      1.107      0.287    -226.231     709.247
# instances_n  1387.7147     65.019     21.343      0.000    1248.262    1527.167
# ==============================================================================
# Omnibus:                        1.607   Durbin-Watson:                   1.032
# Prob(Omnibus):                  0.448   Jarque-Bera (JB):                0.644
# Skew:                           0.489   Prob(JB):                        0.725
# Kurtosis:                       3.100   Cond. No.                         6.95
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /home/godul/.local/lib/python3.7/site-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))
