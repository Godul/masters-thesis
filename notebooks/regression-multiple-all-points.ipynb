# %% [markdown]
# # Multiple regression on all data points (not on means)

# %%
from helpers import (
    add_instances_n,
    draw_regression_graph,
    fit_regression,
    get_experiments_data,
    get_attach_indexes,
    get_data_with_cpu,
)

# %% [markdown]
# ## Redis YCSB 6x10min

# %%
experiment_name = 'redis_ycsb_6x10'

exp_name, df = next(get_data_with_cpu(experiment_name, instances_n=6))

df.head()
# Out:
#    cbtool_time  cpu_time  app_latency  app_throughput     cpu  instances_n
# 0         44.0      44.0     0.078133     9606.147935   213.0          1.0
# 1        105.0     104.0     0.080170     9532.888465   204.0          1.0
# 2        166.0     164.0     0.074826    10362.694301  1686.0          1.0
# 3        227.0     225.0     0.074463    10438.413361  1677.0          1.0
# 4        288.0     285.0     0.078476     9910.802775  1659.0          1.0

# %% [markdown]
# ### `app_latency` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.888
# Model:                            OLS   Adj. R-squared:                  0.887
# Method:                 Least Squares   F-statistic:                     493.7
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           3.19e-31
# Time:                        02:55:50   Log-Likelihood:                 271.72
# No. Observations:                  64   AIC:                            -539.4
# Df Residuals:                      62   BIC:                            -535.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0709      0.001     71.306      0.000       0.069       0.073
# instances_n     0.0057      0.000     22.218      0.000       0.005       0.006
# ==============================================================================
# Omnibus:                        3.976   Durbin-Watson:                   1.454
# Prob(Omnibus):                  0.137   Jarque-Bera (JB):                3.498
# Skew:                           0.572   Prob(JB):                        0.174
# Kurtosis:                       3.046   Cond. No.                         9.18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_latency` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                     369.9
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           7.99e-28
# Time:                        02:55:50   Log-Likelihood:                 263.66
# No. Observations:                  64   AIC:                            -523.3
# Df Residuals:                      62   BIC:                            -519.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0696      0.001     57.559      0.000       0.067       0.072
# cpu         4.613e-06    2.4e-07     19.234      0.000    4.13e-06    5.09e-06
# ==============================================================================
# Omnibus:                        3.220   Durbin-Watson:                   1.111
# Prob(Omnibus):                  0.200   Jarque-Bera (JB):                3.034
# Skew:                           0.526   Prob(JB):                        0.219
# Kurtosis:                       2.818   Cond. No.                     1.22e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.22e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.891
# Model:                            OLS   Adj. R-squared:                  0.887
# Method:                 Least Squares   F-statistic:                     248.2
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           4.92e-30
# Time:                        02:55:51   Log-Likelihood:                 272.34
# No. Observations:                  64   AIC:                            -538.7
# Df Residuals:                      61   BIC:                            -532.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0705      0.001     65.060      0.000       0.068       0.073
# instances_n     0.0046      0.001      4.361      0.000       0.002       0.007
# cpu          9.503e-07   8.66e-07      1.098      0.277   -7.81e-07    2.68e-06
# ==============================================================================
# Omnibus:                        3.577   Durbin-Watson:                   1.388
# Prob(Omnibus):                  0.167   Jarque-Bera (JB):                3.200
# Skew:                           0.547   Prob(JB):                        0.202
# Kurtosis:                       2.970   Cond. No.                     1.34e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm

fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.940
# Method:                 Least Squares   F-statistic:                     981.0
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.03e-39
# Time:                        02:55:52   Log-Likelihood:                -489.52
# No. Observations:                  64   AIC:                             983.0
# Df Residuals:                      62   BIC:                             987.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     498.9322    145.692      3.425      0.001     207.698     790.167
# instances_n  1185.0558     37.835     31.322      0.000    1109.425    1260.687
# ==============================================================================
# Omnibus:                       15.840   Durbin-Watson:                   1.174
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.452
# Skew:                          -1.042   Prob(JB):                     5.97e-05
# Kurtosis:                       4.718   Cond. No.                         9.18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Redis YCSB 12x10min

# %%
experiment_name = 'redis_ycsb_12x10'

exp_name, df = next(get_data_with_cpu(experiment_name, instances_n=12))

df.head()
# Out:
#    cbtool_time  cpu_time  app_latency  app_throughput     cpu  instances_n
# 0         43.0      43.0     0.077327    10000.000000   266.0          1.0
# 1        104.0     103.0     0.074034    10548.523207   827.0          1.0
# 2        165.0     164.0     0.074263    10427.528676  1650.0          1.0
# 3        214.0     214.0     0.074736    10438.413361  1670.0          1.0
# 4        275.0     275.0     0.073540    10548.523207  1638.0          1.0

# %% [markdown]
# ### `app_latency` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.939
# Method:                 Least Squares   F-statistic:                     1936.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.60e-77
# Time:                        02:55:53   Log-Likelihood:                 478.44
# No. Observations:                 126   AIC:                            -952.9
# Df Residuals:                     124   BIC:                            -947.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0686      0.001     66.334      0.000       0.067       0.071
# instances_n     0.0063      0.000     43.996      0.000       0.006       0.007
# ==============================================================================
# Omnibus:                        7.547   Durbin-Watson:                   0.965
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):               10.419
# Skew:                           0.295   Prob(JB):                      0.00546
# Kurtosis:                       4.279   Cond. No.                         15.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_latency` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     802.4
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           5.43e-56
# Time:                        02:55:53   Log-Likelihood:                 428.10
# No. Observations:                 126   AIC:                            -852.2
# Df Residuals:                     124   BIC:                            -846.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0575      0.002     29.540      0.000       0.054       0.061
# cpu          7.43e-06   2.62e-07     28.327      0.000    6.91e-06    7.95e-06
# ==============================================================================
# Omnibus:                       23.664   Durbin-Watson:                   0.519
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.647
# Skew:                           1.011   Prob(JB):                     1.34e-07
# Kurtosis:                       4.392   Cond. No.                     1.99e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.99e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.939
# Method:                 Least Squares   F-statistic:                     970.5
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           4.72e-76
# Time:                        02:55:53   Log-Likelihood:                 479.08
# No. Observations:                 126   AIC:                            -952.2
# Df Residuals:                     123   BIC:                            -943.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0700      0.002     42.443      0.000       0.067       0.073
# instances_n     0.0069      0.001     12.380      0.000       0.006       0.008
# cpu         -7.703e-07   6.85e-07     -1.124      0.263   -2.13e-06    5.86e-07
# ==============================================================================
# Omnibus:                        5.264   Durbin-Watson:                   0.979
# Prob(Omnibus):                  0.072   Jarque-Bera (JB):                6.312
# Skew:                           0.219   Prob(JB):                       0.0426
# Kurtosis:                       4.005   Cond. No.                     2.57e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.57e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.934
# Model:                            OLS   Adj. R-squared:                  0.934
# Method:                 Least Squares   F-statistic:                     1762.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           3.80e-75
# Time:                        02:55:55   Log-Likelihood:                -1006.1
# No. Observations:                 126   AIC:                             2016.
# Df Residuals:                     124   BIC:                             2022.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    1877.1793    135.306     13.874      0.000    1609.371    2144.988
# instances_n   790.7298     18.838     41.974      0.000     753.443     828.016
# ==============================================================================
# Omnibus:                        8.128   Durbin-Watson:                   0.211
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):                8.561
# Skew:                          -0.636   Prob(JB):                       0.0138
# Kurtosis:                       2.879   Cond. No.                         15.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Redis YCSB 12x20min

# %%
experiment_name = 'redis_ycsb_12x20'

exp_name, df = next(get_data_with_cpu(experiment_name, instances_n=12))

df.head()
# Out:
#    cbtool_time  cpu_time  app_latency  app_throughput     cpu  instances_n
# 0         42.0      42.0     0.079693     9487.666034   199.0          1.0
# 1        103.0     102.0     0.078356    10040.160643   207.0          1.0
# 2        164.0     162.0     0.077941     9950.248756  1572.0          1.0
# 3        225.0     223.0     0.076327    10080.645161  1627.0          1.0
# 4        281.0     283.0     0.082048     9199.632015  1655.0          1.0

# %% [markdown]
# ### `app_latency` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.925
# Model:                            OLS   Adj. R-squared:                  0.925
# Method:                 Least Squares   F-statistic:                     2895.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):          9.32e-134
# Time:                        02:55:56   Log-Likelihood:                 875.92
# No. Observations:                 236   AIC:                            -1748.
# Df Residuals:                     234   BIC:                            -1741.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0697      0.001     85.403      0.000       0.068       0.071
# instances_n     0.0062      0.000     53.805      0.000       0.006       0.006
# ==============================================================================
# Omnibus:                       18.553   Durbin-Watson:                   1.170
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.994
# Skew:                           0.526   Prob(JB):                     2.27e-06
# Kurtosis:                       4.240   Cond. No.                         15.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_latency` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.831
# Model:                            OLS   Adj. R-squared:                  0.830
# Method:                 Least Squares   F-statistic:                     1150.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           2.82e-92
# Time:                        02:55:56   Log-Likelihood:                 779.65
# No. Observations:                 236   AIC:                            -1555.
# Df Residuals:                     234   BIC:                            -1548.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0599      0.002     38.752      0.000       0.057       0.063
# cpu         7.135e-06    2.1e-07     33.908      0.000    6.72e-06    7.55e-06
# ==============================================================================
# Omnibus:                       28.363   Durbin-Watson:                   0.650
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.779
# Skew:                           0.874   Prob(JB):                     2.80e-08
# Kurtosis:                       3.694   Cond. No.                     1.95e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.95e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.928
# Model:                            OLS   Adj. R-squared:                  0.927
# Method:                 Least Squares   F-statistic:                     1494.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):          1.33e-133
# Time:                        02:55:56   Log-Likelihood:                 879.83
# No. Observations:                 236   AIC:                            -1754.
# Df Residuals:                     233   BIC:                            -1743.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0724      0.001     58.584      0.000       0.070       0.075
# instances_n     0.0073      0.000     17.652      0.000       0.007       0.008
# cpu         -1.409e-06   5.03e-07     -2.800      0.006    -2.4e-06   -4.18e-07
# ==============================================================================
# Omnibus:                       15.480   Durbin-Watson:                   1.256
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.744
# Skew:                           0.397   Prob(JB):                     4.23e-06
# Kurtosis:                       4.373   Cond. No.                     2.43e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.925
# Model:                            OLS   Adj. R-squared:                  0.925
# Method:                 Least Squares   F-statistic:                     2882.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):          1.53e-133
# Time:                        02:55:58   Log-Likelihood:                -1899.4
# No. Observations:                 236   AIC:                             3803.
# Df Residuals:                     234   BIC:                             3810.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    1861.3874    104.538     17.806      0.000    1655.431    2067.343
# instances_n   794.6421     14.803     53.682      0.000     765.478     823.806
# ==============================================================================
# Omnibus:                       68.579   Durbin-Watson:                   0.527
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              189.456
# Skew:                          -1.272   Prob(JB):                     7.25e-42
# Kurtosis:                       6.577   Cond. No.                         15.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Linpack 6x10min

# %%
experiment_name = 'linpack_6x10'

exp_name, df = next(get_data_with_cpu(experiment_name, instances_n=6))

df.head()
# Out:
#    cbtool_time  cpu_time  app_latency  app_throughput     cpu  instances_n
# 0         42.0      42.0          NaN         33.1012   203.0          1.0
# 1        102.0     102.0          NaN         33.4267   305.0          1.0
# 2        162.0     163.0          NaN         33.2954   553.0          1.0
# 3        222.0     223.0          NaN         33.0314  2030.0          1.0
# 4        282.0     284.0          NaN         33.4075  2047.0          1.0

# %% [markdown]
# ### `app_throughput` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_throughput', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     338.0
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           3.75e-24
# Time:                        02:55:58   Log-Likelihood:                -111.38
# No. Observations:                  53   AIC:                             226.8
# Df Residuals:                      51   BIC:                             230.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      36.8984      0.603     61.158      0.000      35.687      38.110
# instances_n    -3.1649      0.172    -18.385      0.000      -3.511      -2.819
# ==============================================================================
# Omnibus:                        0.238   Durbin-Watson:                   2.119
# Prob(Omnibus):                  0.888   Jarque-Bera (JB):                0.302
# Skew:                          -0.148   Prob(JB):                        0.860
# Kurtosis:                       2.779   Cond. No.                         8.13
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_throughput` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ cpu')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_throughput', variable='cpu')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.802
# Model:                            OLS   Adj. R-squared:                  0.798
# Method:                 Least Squares   F-statistic:                     206.9
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.39e-19
# Time:                        02:55:58   Log-Likelihood:                -122.27
# No. Observations:                  53   AIC:                             248.5
# Df Residuals:                      51   BIC:                             252.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     36.5755      0.745     49.105      0.000      35.080      38.071
# cpu           -0.0019      0.000    -14.384      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                        2.372   Durbin-Watson:                   1.609
# Prob(Omnibus):                  0.305   Jarque-Bera (JB):                1.588
# Skew:                          -0.399   Prob(JB):                        0.452
# Kurtosis:                       3.290   Cond. No.                     1.25e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_throughput` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.864
# Method:                 Least Squares   F-statistic:                     165.8
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           8.63e-23
# Time:                        02:55:59   Log-Likelihood:                -111.37
# No. Observations:                  53   AIC:                             228.7
# Df Residuals:                      50   BIC:                             234.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      36.9110      0.616     59.921      0.000      35.674      38.148
# instances_n    -3.0838      0.611     -5.044      0.000      -4.312      -1.856
# cpu         -5.218e-05      0.000     -0.138      0.890      -0.001       0.001
# ==============================================================================
# Omnibus:                        0.242   Durbin-Watson:                   2.110
# Prob(Omnibus):                  0.886   Jarque-Bera (JB):                0.294
# Skew:                          -0.149   Prob(JB):                        0.863
# Kurtosis:                       2.791   Cond. No.                     1.32e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     579.8
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.62e-29
# Time:                        02:56:00   Log-Likelihood:                -425.50
# No. Observations:                  53   AIC:                             855.0
# Df Residuals:                      51   BIC:                             858.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     241.6925    226.243      1.068      0.290    -212.509     695.894
# instances_n  1554.3836     64.554     24.079      0.000    1424.786    1683.981
# ==============================================================================
# Omnibus:                        4.712   Durbin-Watson:                   1.343
# Prob(Omnibus):                  0.095   Jarque-Bera (JB):                4.604
# Skew:                          -0.686   Prob(JB):                        0.100
# Kurtosis:                       2.548   Cond. No.                         8.13
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Linpack 12x10min

# %%
experiment_name = 'linpack_12x10'

exp_name, df = next(get_data_with_cpu(experiment_name, instances_n=12))

df.head()
# Out:
#    cbtool_time  cpu_time  app_latency  app_throughput     cpu  instances_n
# 0         38.0      38.0          NaN         33.4406   175.0          1.0
# 1         98.0      98.0          NaN         33.4120   428.0          1.0
# 2        158.0     158.0          NaN         33.3477   533.0          1.0
# 3        218.0     219.0          NaN         33.3839  2071.0          1.0
# 4        278.0     280.0          NaN         33.4336  2035.0          1.0

# %% [markdown]
# ### `app_throughput` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n')
draw_regression_graph(results, df, metric_name='app_throughput', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.936
# Method:                 Least Squares   F-statistic:                     1060.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           8.11e-45
# Time:                        02:56:01   Log-Likelihood:                -156.47
# No. Observations:                  74   AIC:                             316.9
# Df Residuals:                      72   BIC:                             321.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      34.5214      0.436     79.144      0.000      33.652      35.391
# instances_n    -2.3877      0.073    -32.560      0.000      -2.534      -2.242
# ==============================================================================
# Omnibus:                        2.672   Durbin-Watson:                   1.040
# Prob(Omnibus):                  0.263   Jarque-Bera (JB):                2.640
# Skew:                          -0.430   Prob(JB):                        0.267
# Kurtosis:                       2.661   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_throughput` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ cpu')
draw_regression_graph(results, df, metric_name='app_throughput', variable='cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     949.2
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           3.34e-43
# Time:                        02:56:01   Log-Likelihood:                -160.28
# No. Observations:                  74   AIC:                             324.6
# Df Residuals:                      72   BIC:                             329.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     37.4869      0.544     68.913      0.000      36.402      38.571
# cpu           -0.0021   6.98e-05    -30.809      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                        0.343   Durbin-Watson:                   1.360
# Prob(Omnibus):                  0.842   Jarque-Bera (JB):                0.501
# Skew:                          -0.128   Prob(JB):                        0.779
# Kurtosis:                       2.689   Cond. No.                     1.71e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.71e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_throughput` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.959
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     835.5
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           4.61e-50
# Time:                        02:56:01   Log-Likelihood:                -140.01
# No. Observations:                  74   AIC:                             286.0
# Df Residuals:                      71   BIC:                             292.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      36.2813      0.449     80.820      0.000      35.386      37.176
# instances_n    -1.3060      0.181     -7.198      0.000      -1.668      -0.944
# cpu            -0.0010      0.000     -6.307      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                        1.237   Durbin-Watson:                   1.709
# Prob(Omnibus):                  0.539   Jarque-Bera (JB):                0.921
# Skew:                          -0.273   Prob(JB):                        0.631
# Kurtosis:                       3.039   Cond. No.                     1.86e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.86e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                     606.0
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           8.61e-37
# Time:                        02:56:03   Log-Likelihood:                -627.28
# No. Observations:                  74   AIC:                             1259.
# Df Residuals:                      72   BIC:                             1263.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    1702.3062    252.821      6.733      0.000    1198.316    2206.297
# instances_n  1046.3685     42.505     24.617      0.000     961.635    1131.102
# ==============================================================================
# Omnibus:                        3.488   Durbin-Watson:                   0.419
# Prob(Omnibus):                  0.175   Jarque-Bera (JB):                3.386
# Skew:                          -0.475   Prob(JB):                        0.184
# Kurtosis:                       2.556   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Linpack 12x20min

# %%
experiment_name = 'linpack_12x20'

exp_name, df = next(get_data_with_cpu(experiment_name, instances_n=12))

df.head()
# Out:
#    cbtool_time  cpu_time  app_latency  app_throughput     cpu  instances_n
# 0         44.0      44.0          NaN         32.8908   180.0          1.0
# 1        104.0     104.0          NaN         33.4394   427.0          1.0
# 2        164.0     165.0          NaN         33.2988  1244.0          1.0
# 3        224.0     225.0          NaN         33.4386  2035.0          1.0
# 4        284.0     285.0          NaN         33.4588  2034.0          1.0

# %% [markdown]
# ### `app_throughput` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n')
draw_regression_graph(results, df, metric_name='app_throughput', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.928
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                     1977.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           2.14e-89
# Time:                        02:56:03   Log-Likelihood:                -341.02
# No. Observations:                 155   AIC:                             686.0
# Df Residuals:                     153   BIC:                             692.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      34.5753      0.332    104.068      0.000      33.919      35.232
# instances_n    -2.3285      0.052    -44.465      0.000      -2.432      -2.225
# ==============================================================================
# Omnibus:                        6.219   Durbin-Watson:                   1.122
# Prob(Omnibus):                  0.045   Jarque-Bera (JB):                6.187
# Skew:                          -0.489   Prob(JB):                       0.0454
# Kurtosis:                       3.010   Cond. No.                         12.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_throughput` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ cpu')
draw_regression_graph(results, df, metric_name='app_throughput', variable='cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.908
# Model:                            OLS   Adj. R-squared:                  0.907
# Method:                 Least Squares   F-statistic:                     1511.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           3.39e-81
# Time:                        02:56:04   Log-Likelihood:                -360.14
# No. Observations:                 155   AIC:                             724.3
# Df Residuals:                     153   BIC:                             730.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     38.2653      0.462     82.792      0.000      37.352      39.178
# cpu           -0.0022   5.53e-05    -38.878      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                        0.241   Durbin-Watson:                   1.215
# Prob(Omnibus):                  0.887   Jarque-Bera (JB):                0.182
# Skew:                           0.083   Prob(JB):                        0.913
# Kurtosis:                       2.980   Cond. No.                     1.93e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.93e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_throughput` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.942
# Method:                 Least Squares   F-statistic:                     1255.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           3.18e-95
# Time:                        02:56:04   Log-Likelihood:                -323.24
# No. Observations:                 155   AIC:                             652.5
# Df Residuals:                     152   BIC:                             661.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      36.3838      0.414     87.793      0.000      35.565      37.203
# instances_n    -1.4395      0.150     -9.628      0.000      -1.735      -1.144
# cpu            -0.0009      0.000     -6.262      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                        3.982   Durbin-Watson:                   1.542
# Prob(Omnibus):                  0.137   Jarque-Bera (JB):                3.511
# Skew:                          -0.301   Prob(JB):                        0.173
# Kurtosis:                       3.425   Cond. No.                     2.23e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.23e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.902
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     1406.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           5.21e-79
# Time:                        02:56:06   Log-Likelihood:                -1309.8
# No. Observations:                 155   AIC:                             2624.
# Df Residuals:                     153   BIC:                             2630.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    2069.4302    172.148     12.021      0.000    1729.336    2409.524
# instances_n  1017.2633     27.134     37.491      0.000     963.658    1070.869
# ==============================================================================
# Omnibus:                        1.559   Durbin-Watson:                   0.236
# Prob(Omnibus):                  0.459   Jarque-Bera (JB):                1.602
# Skew:                          -0.234   Prob(JB):                        0.449
# Kurtosis:                       2.832   Cond. No.                         12.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Wrk 6x10min

# %%
experiment_name = 'wrk_6x10'

exp_name, df = next(get_data_with_cpu(experiment_name, instances_n=6))
df = df.drop([0, 1])

df.head()
# Out:
#    cbtool_time  cpu_time  app_latency  app_throughput     cpu  instances_n
# 2        624.0     627.0        22.28          7080.0  6295.0          1.0
# 3        688.0     688.0        26.35          6380.0  7917.0          1.0
# 4        753.0     749.0        34.40          6280.0  8709.0          2.0
# 5        980.0     982.0        33.50          4450.0  9394.0          2.0
# 6       1045.0    1042.0        21.87          9190.0  9750.0          2.0

# %% [markdown]
# ### `app_latency` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     305.3
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           9.78e-13
# Time:                        02:56:06   Log-Likelihood:                -57.931
# No. Observations:                  20   AIC:                             119.9
# Df Residuals:                      18   BIC:                             121.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       9.2694      2.670      3.472      0.003       3.660      14.879
# instances_n    11.6264      0.665     17.473      0.000      10.228      13.024
# ==============================================================================
# Omnibus:                        6.729   Durbin-Watson:                   1.937
# Prob(Omnibus):                  0.035   Jarque-Bera (JB):                4.641
# Skew:                          -1.152   Prob(JB):                       0.0982
# Kurtosis:                       3.509   Cond. No.                         10.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_latency` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.738
# Model:                            OLS   Adj. R-squared:                  0.723
# Method:                 Least Squares   F-statistic:                     50.62
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.25e-06
# Time:                        02:56:06   Log-Likelihood:                -73.431
# No. Observations:                  20   AIC:                             150.9
# Df Residuals:                      18   BIC:                             152.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -66.4088     16.833     -3.945      0.001    -101.774     -31.044
# cpu            0.0116      0.002      7.115      0.000       0.008       0.015
# ==============================================================================
# Omnibus:                        6.100   Durbin-Watson:                   1.288
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                3.710
# Skew:                          -0.957   Prob(JB):                        0.156
# Kurtosis:                       3.888   Cond. No.                     7.74e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.74e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.942
# Method:                 Least Squares   F-statistic:                     155.0
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.22e-11
# Time:                        02:56:06   Log-Likelihood:                -57.245
# No. Observations:                  20   AIC:                             120.5
# Df Residuals:                      17   BIC:                             123.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      23.6056     13.313      1.773      0.094      -4.483      51.695
# instances_n    13.2200      1.594      8.294      0.000       9.857      16.583
# cpu            -0.0020      0.002     -1.099      0.287      -0.006       0.002
# ==============================================================================
# Omnibus:                        3.742   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.154   Jarque-Bera (JB):                2.599
# Skew:                          -0.883   Prob(JB):                        0.273
# Kurtosis:                       2.954   Cond. No.                     1.34e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.828
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     86.49
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           2.70e-08
# Time:                        02:56:08   Log-Likelihood:                -155.28
# No. Observations:                  20   AIC:                             314.6
# Df Residuals:                      18   BIC:                             316.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    7237.2884    347.102     20.851      0.000    6508.054    7966.523
# instances_n   804.4896     86.506      9.300      0.000     622.748     986.231
# ==============================================================================
# Omnibus:                        9.492   Durbin-Watson:                   1.140
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                7.319
# Skew:                          -1.026   Prob(JB):                       0.0257
# Kurtosis:                       5.139   Cond. No.                         10.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Wrk 12x10min

# %%
experiment_name = 'wrk_12x10'

exp_name, df = next(get_data_with_cpu(experiment_name, instances_n=12))
df = df.drop([0, 1])

df.head()
# Out:
#    cbtool_time  cpu_time  app_latency  app_throughput     cpu  instances_n
# 2        908.0     911.0        31.04          3110.0  9134.0          2.0
# 3        973.0     972.0        31.92          4100.0  9469.0          2.0
# 4       1038.0    1033.0        32.15          4050.0  9717.0          2.0
# 5       1331.0    1336.0        38.40          4800.0  9387.0          2.0
# 6       1397.0    1397.0        38.99          7400.0  9225.0          3.0

# %% [markdown]
# ### `app_latency` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                     1513.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           5.23e-31
# Time:                        02:56:08   Log-Likelihood:                -111.95
# No. Observations:                  38   AIC:                             227.9
# Df Residuals:                      36   BIC:                             231.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      17.4174      1.854      9.395      0.000      13.658      21.177
# instances_n     9.6676      0.249     38.897      0.000       9.164      10.172
# ==============================================================================
# Omnibus:                        0.093   Durbin-Watson:                   1.652
# Prob(Omnibus):                  0.955   Jarque-Bera (JB):                0.025
# Skew:                          -0.028   Prob(JB):                        0.988
# Kurtosis:                       2.887   Cond. No.                         18.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_latency` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.776
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                     124.8
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           2.98e-13
# Time:                        02:56:09   Log-Likelihood:                -154.99
# No. Observations:                  38   AIC:                             314.0
# Df Residuals:                      36   BIC:                             317.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -274.5519     32.101     -8.553      0.000    -339.656    -209.448
# cpu            0.0319      0.003     11.171      0.000       0.026       0.038
# ==============================================================================
# Omnibus:                        2.036   Durbin-Watson:                   0.570
# Prob(Omnibus):                  0.361   Jarque-Bera (JB):                1.766
# Skew:                           0.514   Prob(JB):                        0.414
# Kurtosis:                       2.757   Cond. No.                     1.52e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.52e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.982
# Method:                 Least Squares   F-statistic:                     983.5
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.76e-31
# Time:                        02:56:09   Log-Likelihood:                -106.54
# No. Observations:                  38   AIC:                             219.1
# Df Residuals:                      35   BIC:                             224.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     -33.0832     14.962     -2.211      0.034     -63.457      -2.709
# instances_n     8.4643      0.416     20.329      0.000       7.619       9.310
# cpu             0.0052      0.002      3.396      0.002       0.002       0.008
# ==============================================================================
# Omnibus:                        6.456   Durbin-Watson:                   2.211
# Prob(Omnibus):                  0.040   Jarque-Bera (JB):                5.062
# Skew:                           0.733   Prob(JB):                       0.0796
# Kurtosis:                       4.024   Cond. No.                     2.49e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.49e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.724
# Model:                            OLS   Adj. R-squared:                  0.717
# Method:                 Least Squares   F-statistic:                     94.59
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.30e-11
# Time:                        02:56:10   Log-Likelihood:                -285.05
# No. Observations:                  38   AIC:                             574.1
# Df Residuals:                      36   BIC:                             577.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    9652.2618    176.377     54.725      0.000    9294.553       1e+04
# instances_n   229.9808     23.647      9.725      0.000     182.022     277.940
# ==============================================================================
# Omnibus:                        3.304   Durbin-Watson:                   0.446
# Prob(Omnibus):                  0.192   Jarque-Bera (JB):                2.871
# Skew:                          -0.667   Prob(JB):                        0.238
# Kurtosis:                       2.817   Cond. No.                         18.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Wrk 12x20min

# %%
experiment_name = 'wrk_12x20'

exp_name, df = next(get_data_with_cpu(experiment_name, instances_n=12))
df = df.drop([0, 1])

df.head()
# Out:
#    cbtool_time  cpu_time  app_latency  app_throughput     cpu  instances_n
# 2        420.0     422.0        19.59          7010.0  5906.0          1.0
# 3        483.0     483.0        15.15          8870.0  7869.0          1.0
# 4        547.0     543.0        20.96          5360.0  8022.0          1.0
# 5        962.0     967.0        15.33          8900.0  6597.0          1.0
# 6       1026.0    1028.0        20.42          5340.0  6163.0          1.0

# %% [markdown]
# ### `app_latency` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n')
draw_regression_graph(results, df, metric_name='app_latency', variable='instances_n')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.964
# Method:                 Least Squares   F-statistic:                     1988.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.05e-54
# Time:                        02:56:11   Log-Likelihood:                -248.97
# No. Observations:                  75   AIC:                             501.9
# Df Residuals:                      73   BIC:                             506.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      14.7613      1.617      9.128      0.000      11.538      17.984
# instances_n    10.0897      0.226     44.590      0.000       9.639      10.541
# ==============================================================================
# Omnibus:                        0.528   Durbin-Watson:                   1.532
# Prob(Omnibus):                  0.768   Jarque-Bera (JB):                0.147
# Skew:                           0.061   Prob(JB):                        0.929
# Kurtosis:                       3.180   Cond. No.                         15.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_latency` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ cpu')
draw_regression_graph(results, df, metric_name='app_latency', variable='cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.702
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     172.2
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           6.86e-21
# Time:                        02:56:11   Log-Likelihood:                -328.81
# No. Observations:                  75   AIC:                             661.6
# Df Residuals:                      73   BIC:                             666.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -149.9542     17.508     -8.565      0.000    -184.847    -115.062
# cpu            0.0210      0.002     13.123      0.000       0.018       0.024
# ==============================================================================
# Omnibus:                       11.226   Durbin-Watson:                   0.510
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               12.245
# Skew:                           0.987   Prob(JB):                      0.00219
# Kurtosis:                       3.134   Cond. No.                     8.43e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_latency` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_latency ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            app_latency   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     1211.
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           3.79e-56
# Time:                        02:56:12   Log-Likelihood:                -241.32
# No. Observations:                  75   AIC:                             488.6
# Df Residuals:                      72   BIC:                             495.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     -15.2039      7.565     -2.010      0.048     -30.285      -0.123
# instances_n     8.9650      0.346     25.891      0.000       8.275       9.655
# cpu             0.0034      0.001      4.038      0.000       0.002       0.005
# ==============================================================================
# Omnibus:                       13.382   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               17.411
# Skew:                           0.773   Prob(JB):                     0.000166
# Kurtosis:                       4.784   Cond. No.                     1.16e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.16e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.647
# Model:                            OLS   Adj. R-squared:                  0.642
# Method:                 Least Squares   F-statistic:                     133.8
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           3.59e-18
# Time:                        02:56:13   Log-Likelihood:                -611.62
# No. Observations:                  75   AIC:                             1227.
# Df Residuals:                      73   BIC:                             1232.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    8778.6660    203.584     43.121      0.000    8372.923    9184.409
# instances_n   329.4841     28.485     11.567      0.000     272.713     386.255
# ==============================================================================
# Omnibus:                       33.384   Durbin-Watson:                   0.420
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.384
# Skew:                          -1.602   Prob(JB):                     2.33e-15
# Kurtosis:                       6.361   Cond. No.                         15.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Hadoop 6x20min

# %%
experiment_name = 'hadoop_6x20'

exp_name, df = next(get_data_with_cpu(experiment_name, instances_n=6))
# df = df.drop([0, 1])

df.head()
# Out:
#    cbtool_time  cpu_time  app_latency  app_throughput     cpu  instances_n
# 0        306.0     306.0      24710.0         40469.0   773.0          1.0
# 1        716.0     719.0      24527.0         40771.0  1727.0          1.0
# 2        784.0     779.0      25673.0         38951.0  1709.0          1.0
# 3       1258.0    1263.0      25273.0         39567.0  1814.0          1.0
# 4       1324.0    1324.0      23754.0         42098.0  1450.0          1.0

# %% [markdown]
# ### `app_throughput` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_throughput', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.872
# Method:                 Least Squares   F-statistic:                     130.7
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.10e-09
# Time:                        02:56:13   Log-Likelihood:                -173.12
# No. Observations:                  20   AIC:                             350.2
# Df Residuals:                      18   BIC:                             352.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     4.26e+04    678.346     62.801      0.000    4.12e+04     4.4e+04
# instances_n -2301.5184    201.351    -11.430      0.000   -2724.541   -1878.496
# ==============================================================================
# Omnibus:                        2.010   Durbin-Watson:                   2.541
# Prob(Omnibus):                  0.366   Jarque-Bera (JB):                1.056
# Skew:                          -0.114   Prob(JB):                        0.590
# Kurtosis:                       1.898   Cond. No.                         7.46
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### `app_throughput` ~ `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ cpu')
print(results.summary())
draw_regression_graph(results, df, metric_name='app_throughput', variable='cpu')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.714
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     45.01
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           2.73e-06
# Time:                        02:56:13   Log-Likelihood:                -181.70
# No. Observations:                  20   AIC:                             367.4
# Df Residuals:                      18   BIC:                             369.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.175e+04   1018.275     41.001      0.000    3.96e+04    4.39e+04
# cpu           -1.3696      0.204     -6.709      0.000      -1.799      -0.941
# ==============================================================================
# Omnibus:                        6.867   Durbin-Watson:                   2.540
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                4.293
# Skew:                          -0.963   Prob(JB):                        0.117
# Kurtosis:                       4.202   Cond. No.                     1.01e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### `app_throughput` ~ `instances_n` + `cpu`

# %%
results = fit_regression(data=df, formula='app_throughput ~ instances_n + cpu')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_throughput   R-squared:                       0.898
# Model:                            OLS   Adj. R-squared:                  0.886
# Method:                 Least Squares   F-statistic:                     75.07
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           3.65e-09
# Time:                        02:56:14   Log-Likelihood:                -171.38
# No. Observations:                  20   AIC:                             348.8
# Df Residuals:                      17   BIC:                             351.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    4.253e+04    640.907     66.362      0.000    4.12e+04    4.39e+04
# instances_n -3324.9348    599.654     -5.545      0.000   -4590.095   -2059.775
# cpu             0.7122      0.396      1.799      0.090      -0.123       1.547
# ==============================================================================
# Omnibus:                        2.158   Durbin-Watson:                   2.137
# Prob(Omnibus):                  0.340   Jarque-Bera (JB):                1.535
# Skew:                          -0.667   Prob(JB):                        0.464
# Kurtosis:                       2.755   Cond. No.                     1.11e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.11e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Single variable plots

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "instances_n", fig=fig)

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(results, "cpu", fig=fig)

# %% [markdown]
# ### `cpu` ~ `instances_n`

# %%
results = fit_regression(data=df, formula='cpu ~ instances_n')
print(results.summary())
draw_regression_graph(results, df, metric_name='cpu', variable='instances_n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpu   R-squared:                       0.900
# Model:                            OLS   Adj. R-squared:                  0.894
# Method:                 Least Squares   F-statistic:                     161.5
# Date:                Wed, 17 Jun 2020   Prob (F-statistic):           1.99e-10
# Time:                        02:56:15   Log-Likelihood:                -161.58
# No. Observations:                  20   AIC:                             327.2
# Df Residuals:                      18   BIC:                             329.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      97.2531    380.948      0.255      0.801    -703.090     897.596
# instances_n  1436.9651    113.075     12.708      0.000    1199.402    1674.528
# ==============================================================================
# Omnibus:                        7.881   Durbin-Watson:                   2.189
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                5.322
# Skew:                          -0.963   Prob(JB):                       0.0699
# Kurtosis:                       4.637   Cond. No.                         7.46
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
